# %%
# ==============================================================================
# STEP 1: SETUP, CONFIGURATION, AND IMPORTS (REVISED FOR LATE FUSION)
# ==============================================================================
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, applications, optimizers
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from PIL import Image
from tqdm import tqdm
from google.colab import drive
import matplotlib.pyplot as plt

# --- Code to Mount Google Drive (Run this first in Colab) ---
drive.mount('/content/gdrive')
# -----------------------------------------------------------

# --- Configuration ---
# CRITICAL: Ensure DRIVE_PATH points to the directory containing
# 'final_zimbabwe_property_listings_complete.csv' AND the 'images' folder.
DRIVE_PATH = '/content/gdrive/MyDrive/Deep Learning/'
CSV_FILENAME = os.path.join(DRIVE_PATH, 'final_zimbabwe_property_listings_complete.csv')
IMAGE_FOLDER_NAME = 'images'
# --- Hyperparameters (Tuning Applied) ---
IMG_WIDTH, IMG_HEIGHT, CHANNELS = 128, 128, 3
EPOCHS = 30 # Tuned value
BATCH_SIZE = 32
LEARNING_RATE = 5e-4 # Tuned value
FINE_TUNE = False

# List of CNN backbones to test
CNN_BACKBONES = [
    'AlexNet', 'NiN', 'ZNet', 'VGG', 'Google LeNet', 'InceptionV3',
    'Highway', 'InceptionV4', 'ResNet', 'InceptionV4 ResNet',
    'FractalNet', 'WideResNet', 'Xception', 'Residual Attention Neural Network',
    'Squeeze and Excitation Networks', 'Competitive Squeeze and Excitation Network',
    'DenseNet', 'MobileNet V2', 'Capsulenet', 'HRNet V2'
]

# Shared dense layer configurations
TABULAR_DENSE_LAYERS = [128, 64]
# PREDICTION_HEAD_LAYERS now acts as the prediction head layers for both branches
PREDICTION_HEAD_LAYERS = [128, 64]

print(f"Configuration Complete. Image size: {IMG_WIDTH}x{IMG_HEIGHT}. Epochs: {EPOCHS}, LR: {LEARNING_RATE}")
# Ensure we are in the correct directory for file operations
os.chdir(DRIVE_PATH)

# ==============================================================================
# STEP 2: DATA LOADING, PREPROCESSING, AND LOG SCALING
# ==============================================================================

print('\nLoading CSV data and preparing tabular features...')
df = pd.read_csv(CSV_FILENAME)

IMAGE_FILENAME_COLUMN = 'image_filenames'

# Drop rows where 'price' or the image filename is missing
df.dropna(subset=['price', IMAGE_FILENAME_COLUMN], inplace=True)

# Define features and target
tabular_features = [
    'bedrooms', 'bathrooms', 'land_area', 'building_area',
    'property_type', 'location'
]
target = 'price'

# Filter DataFrame and impute missing values
df_filtered = df[tabular_features + [target, IMAGE_FILENAME_COLUMN]].copy()

# Impute numerical features with the median
for col in ['bedrooms', 'bathrooms', 'land_area', 'building_area']:
    df_filtered.loc[:, col] = df_filtered[col].fillna(df_filtered[col].median())

# Impute categorical features with 'Unknown'
for col in ['property_type', 'location']:
    df_filtered.loc[:, col] = df_filtered[col].fillna('Unknown')

X = df_filtered[tabular_features]
y = df_filtered[target].values
image_filenames = df_filtered[IMAGE_FILENAME_COLUMN].values.astype(str)

# --- Define Preprocessing Pipelines for Tabular Features (X) ---
numerical_features = X.select_dtypes(include=np.number).columns.tolist()
categorical_features = X.select_dtypes(include=['object']).columns.tolist()

numerical_transformer = Pipeline(steps=[('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ],
    remainder='passthrough'
)

# Apply preprocessing to X
X_tabular = preprocessor.fit_transform(X).toarray()
tabular_input_shape = (X_tabular.shape[1],)
print(f"Tabular data shape after preprocessing: {X_tabular.shape}")


# --- CRITICAL FIX: LOG TRANSFORM THE TARGET VARIABLE (y) ---
y_target_log = np.log1p(y)
target_scaler = StandardScaler()
y_target_scaled = target_scaler.fit_transform(y_target_log.reshape(-1, 1)).flatten()
y_target = y_target_scaled

print("\n✅ Target variable 'price' has been Log-Transformed and Standard Scaled for maximum stability.")


# ==============================================================================
# STEP 3: IMAGE AND MASK PREPARATION (REVISED FOR FULL DATASET)
# ==============================================================================

def load_and_preprocess_image_data_with_mask(filenames, drive_path=DRIVE_PATH, image_folder=IMAGE_FOLDER_NAME):
    """Loads images or a zero-image placeholder, and generates a binary mask."""
    image_dir = os.path.join(drive_path, image_folder)
    images = []
    image_masks = []

    available_files = set()
    try:
        if not os.path.exists(image_dir):
            raise FileNotFoundError(f"Image directory not found at {image_dir}")
        available_files = set(os.listdir(image_dir))
        print(f"Found image directory at {image_dir}.")
    except FileNotFoundError as e:
        print(f"ERROR: {e}. Assuming no images are available. Check DRIVE_PATH and image_folder.")

    print("\nPreparing image data with masking strategy...")

    for filename in tqdm(filenames, desc="Loading Images and Creating Masks"):
        path = filename

        if path in available_files:
            try:
                # Load, resize, and normalize the actual image
                img = Image.open(os.path.join(image_dir, path)).convert('RGB')
                img = img.resize((IMG_WIDTH, IMG_HEIGHT))
                img_arr = img_to_array(img).astype('float32') / 255.0
                images.append(img_arr)
                image_masks.append(1.0) # Mask is 1 (Image is present)
            except Exception:
                # Fallback if image exists but is corrupted
                images.append(np.zeros((IMG_HEIGHT, IMG_WIDTH, CHANNELS), dtype=np.float32))
                image_masks.append(0.0) # Treat as missing
        else:
            # Placeholder for missing images
            images.append(np.zeros((IMG_HEIGHT, IMG_WIDTH, CHANNELS), dtype=np.float32))
            image_masks.append(0.0) # Mask is 0 (Image is missing)

    image_data = np.array(images)
    image_masks = np.array(image_masks)
    image_input_shape = image_data.shape[1:]

    print(f"Total records processed: {len(image_data)}. Records with images: {int(np.sum(image_masks))}")
    print(f"Image data shape: {image_data.shape}. Mask shape: {image_masks.shape}")

    return image_data, image_input_shape, image_masks

# Execute loading and masking
image_data, image_input_shape, image_masks = load_and_preprocess_image_data_with_mask(image_filenames)

# Perform the final Train/Test Split (including the mask array)
X_tab_train, X_tab_test, X_img_train, X_img_test, y_train, y_test, X_mask_train, X_mask_test = train_test_split(
    X_tabular, image_data, y_target, image_masks, test_size=0.2, random_state=42
)
print(f"\nTraining samples: {len(y_train)}, Test samples: {len(y_test)}")

# ==============================================================================
# STEP 4: CNN STUB AND MODEL BUILDER DEFINITIONS (REVISION: HUBER Loss + LATE FUSION)
# ==============================================================================

# --- CNN Stubs (Feature Extraction) ---

def nin_block(x, num_channels, block_name):
    x = layers.Conv2D(num_channels, (5, 5), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.Conv2D(num_channels, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.Conv2D(num_channels, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    return x

def nin_net(input_tensor, name='NiN'):
    x = nin_block(input_tensor, 32, block_name=f'{name}_b1')
    x = layers.MaxPooling2D((3, 3), strides=(2, 2))(x)
    x = nin_block(x, 64, block_name=f'{name}_b2')
    x = layers.GlobalAveragePooling2D(name=f'{name}_avg_pool')(x)
    return x

def alexnet_block(input_tensor, name='AlexNet'):
    x = layers.Conv2D(96, (11, 11), strides=(4, 4), activation='relu', name=f'{name}_conv1')(input_tensor)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), name=f'{name}_pool1')(x)
    x = layers.Conv2D(256, (5, 5), activation='relu', padding='same', name=f'{name}_conv2')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), name=f'{name}_pool2')(x)
    x = layers.Conv2D(384, (3, 3), activation='relu', padding='same', name=f'{name}_conv3')(x)
    x = layers.Conv2D(384, (3, 3), activation='relu', padding='same', name=f'{name}_conv4')(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name=f'{name}_conv5')(x)
    x = layers.GlobalAveragePooling2D(name=f'{name}_avg_pool')(x)
    return x

# Placeholder stubs for other models
def znet_stub(input_tensor):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.GlobalAveragePooling2D()(x)
    return x
def googlenet_stub(input_tensor):
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(input_tensor)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = layers.GlobalAveragePooling2D()(x)
    return x
def highway_stub(input_tensor):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.GlobalAveragePooling2D()(x)
    return x
def inceptionv4_stub(input_tensor):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.GlobalAveragePooling2D()(x)
    return x
def fractalnet_stub(input_tensor):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.GlobalAveragePooling2D()(x)
    return x
def wideresnet_stub(input_tensor):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.GlobalAveragePooling2D()(x)
    return x
def res_attention_stub(input_tensor):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.GlobalAveragePooling2D()(x)
    return x
def senet_stub(input_tensor):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.GlobalAveragePooling2D()(x)
    return x
def comp_senet_stub(input_tensor):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.GlobalAveragePooling2D()(x)
    return x
def capsulenet_stub(input_tensor):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.GlobalAveragePooling2D()(x)
    return x
def hrnet_stub(input_tensor):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.GlobalAveragePooling2D()(x)
    return x


# --- Dual Input - Model Builder (LATE FUSION) ---
def build_fusion_model_with_cnn(cnn_name, tab_shape, img_shape, fine_tune_flag, tab_units, prediction_units):
    """Creates a Dual Input - Late Prediction Fusion model with masking and Huber loss."""

    safe_cnn_name = cnn_name.replace(' ', '_').replace('-', '_')

    # --- Branch 1: Tabular Feature Extraction (MLP) ---
    tab_input = layers.Input(shape=tab_shape, name="tabular_input")
    x_tab = tab_input
    for units in tab_units:
        x_tab = layers.Dense(units, activation='relu')(x_tab)
        x_tab = layers.Dropout(0.3)(x_tab)
    # Final feature vector for tabular branch
    tab_features = layers.Dense(64, activation='relu', name="tab_dense_out")(x_tab)

    # --- Branch 2: Image Feature Extraction (CNN) ---
    img_input = layers.Input(shape=img_shape, name="image_input")

    # --- Branch 3: Mask Input (Scalar 0 or 1) ---
    mask_input = layers.Input(shape=(1,), name="mask_input")

    # A. Keras Applications Mapping (Pre-trained models)
    BACKBONE_MAP = {
        'VGG': applications.VGG16,
        'InceptionV3': applications.InceptionV3,
        'ResNet': applications.ResNet50,
        'InceptionV4 ResNet': applications.InceptionResNetV2,
        'Xception': applications.Xception,
        'DenseNet': applications.DenseNet121,
        'MobileNet V2': applications.MobileNetV2
    }

    x_img = None
    if cnn_name in BACKBONE_MAP:
        BaseModel = BACKBONE_MAP[cnn_name]
        base_cnn = BaseModel(
            weights='imagenet', include_top=False, input_tensor=img_input
        )
        base_cnn.trainable = fine_tune_flag
        x_img = base_cnn.output
        x_img = layers.GlobalAveragePooling2D(name=f'{safe_cnn_name}_avg_pool')(x_img)

    # B. Custom Stubs Mapping
    elif cnn_name == 'AlexNet':
        x_img = alexnet_block(img_input)
    elif cnn_name == 'NiN':
        x_img = nin_net(img_input)
    elif cnn_name == 'ZNet':
        x_img = znet_stub(img_input)
    elif cnn_name == 'Google LeNet':
        x_img = googlenet_stub(img_input)
    elif cnn_name == 'Highway':
        x_img = highway_stub(img_input)
    elif cnn_name == 'InceptionV4':
        x_img = inceptionv4_stub(img_input)
    elif cnn_name == 'FractalNet':
        x_img = fractalnet_stub(img_input)
    elif cnn_name == 'WideResNet':
        x_img = wideresnet_stub(img_input)
    elif cnn_name == 'Residual Attention Neural Network':
        x_img = res_attention_stub(img_input)
    elif cnn_name == 'Squeeze and Excitation Networks':
        x_img = senet_stub(img_input)
    elif cnn_name == 'Competitive Squeeze and Excitation Network':
        x_img = comp_senet_stub(img_input)
    elif cnn_name == 'Capsulenet':
        x_img = capsulenet_stub(img_input)
    elif cnn_name == 'HRNet V2':
        x_img = hrnet_stub(img_input)
    else:
        raise ValueError(f"Unknown CNN backbone: {cnn_name}")

    # Feature vector for image branch
    img_features = layers.Dense(64, activation='relu', name="img_dense_pre_mask")(x_img)

    # CRITICAL MASKING STEP: Disable image features if mask is 0
    img_features_masked = layers.multiply([img_features, mask_input], name="masked_img_features")

    # 🔥 LATE PREDICTION FUSION ARCHITECTURE 🔥

    # 1. Tabular Prediction Head
    x_tab_pred = tab_features
    for units in prediction_units:
        x_tab_pred = layers.Dense(units, activation='relu')(x_tab_pred)
    tab_output = layers.Dense(1, name="tabular_prediction_output")(x_tab_pred)

    # 2. Image Prediction Head
    x_img_pred = img_features_masked
    for units in prediction_units:
        x_img_pred = layers.Dense(units, activation='relu')(x_img_pred)
    img_output = layers.Dense(1, name="image_prediction_output")(x_img_pred)

    # 3. Hybridization/Averaging (combines the two individual predictions)
    # The final prediction is the average of the two separate learning pathways.
    final_output = layers.Average(name="final_hybrid_prediction")([tab_output, img_output])

    # Build and compile the model
    model = models.Model(inputs=[tab_input, img_input, mask_input], outputs=final_output, name=safe_cnn_name)

    optimizer = optimizers.Adam(learning_rate=LEARNING_RATE)

    # Use Huber Loss for robustness
    model.compile(loss=tf.keras.losses.Huber(delta=1.0), optimizer=optimizer, metrics=['mae'])
    return model


# ==============================================================================
# STEP 5: TRAINING, PREDICTION, AND EVALUATION LOOP (REVISED FOR OUTPUT DISPLAY)
# ==============================================================================
results = []
best_model_name = None
best_rmse = np.inf
best_history = None
best_predictions = None
best_true_values = None

print(f"\nStarting sequential training of the 20 CNN-backed models (Tuning: EPOCHS={EPOCHS}, LR={LEARNING_RATE}, Loss=Huber, Architecture=Late Fusion)...")

# --- Revised Plotting Function for Per-Model Visualization (Display Only) ---
def plot_actual_vs_predicted_per_model(y_true, y_pred, model_name):
    """Generates and displays a scatter plot of Actual vs. Predicted prices."""
    plt.figure(figsize=(8, 5))
    plt.scatter(y_true, y_pred, alpha=0.6, s=15)

    # Determine plot limits for the y=x line
    min_val = max(0, min(y_true.min(), y_pred.min()))
    max_val = max(y_true.max(), y_pred.max())

    plt.plot([min_val, max_val], [min_val, max_val], 'r--', label='Ideal Prediction (y=x)')
    plt.xlabel("Actual Price (USD)")
    plt.ylabel("Predicted Price (USD)")
    plt.title(f"{model_name}: Actual vs. Predicted Prices")
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()

    # CRITICAL CHANGE: Use plt.show() instead of plt.savefig()
    plt.show()
    plt.close() # Close the figure to free memory

# -----------------------------------------------------------------------------

for i, cnn_name in enumerate(CNN_BACKBONES):
    # Clear session to prevent memory leaks/corruption between models
    K.clear_session()
    print(f"\n================ Model {i+1}/20: {cnn_name} ================")

    try:
        model = build_fusion_model_with_cnn(
            cnn_name=cnn_name,
            tab_shape=tabular_input_shape,
            img_shape=image_input_shape,
            fine_tune_flag=FINE_TUNE,
            tab_units=TABULAR_DENSE_LAYERS,
            prediction_units=PREDICTION_HEAD_LAYERS
        )

        # Define the training and validation data dictionaries (including mask)
        train_data = {
            "tabular_input": X_tab_train,
            "image_input": X_img_train,
            "mask_input": X_mask_train.reshape(-1, 1) # Mask must be reshaped to (N, 1)
        }
        test_data = {
            "tabular_input": X_tab_test,
            "image_input": X_img_test,
            "mask_input": X_mask_test.reshape(-1, 1)  # Mask must be reshaped to (N, 1)
        }

        # 2. Train the Model
        print(f"Training {cnn_name}...")
        history = model.fit(
            x=train_data,
            y=y_train,
            validation_data=(test_data, y_test),
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            verbose=2
        )

        # 3. Predict on Test Set (Scaled Output)
        y_pred_scaled = model.predict(test_data).flatten()

        # 4. Inverse Transform Predictions and True Values (Log Scaling Inverse)
        y_test_log = target_scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
        y_pred_log = target_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

        # Step 4b: Inverse Log the values to get original currency (exp(x) - 1)
        y_test_original = np.expm1(y_test_log)
        y_pred_original = np.expm1(y_pred_log)

        # Ensure prices are non-negative
        y_test_original[y_test_original < 0] = 0
        y_pred_original[y_pred_original < 0] = 0

        # 5. Evaluate with Original Values
        mae = mean_absolute_error(y_test_original, y_pred_original)
        mse = mean_squared_error(y_test_original, y_pred_original)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_test_original, y_pred_original)

        # --- NEW CODE: Display Plot in Output Tab ---
        print(f"   Displaying Actual vs. Predicted plot for {cnn_name}...")
        plot_actual_vs_predicted_per_model(
            y_test_original, y_pred_original, cnn_name
        )
        # ---------------------------

        print(f"Training Complete. | *RMSE: {rmse:,.2f}* | MAE: {mae:,.2f} | R2: {r2:.4f}")

        # Store results and track the best model
        results.append({
            'Model Name': cnn_name,
            'RMSE': rmse, 'MAE': mae, 'R2': r2, 'Notes': 'Successful'
        })
        if rmse < best_rmse:
            best_rmse = rmse
            best_model_name = cnn_name
            best_history = history
            best_predictions = y_pred_original
            best_true_values = y_test_original

    except Exception as e:
        print(f"❌ Error training {cnn_name}. Skipping. Error: {e}")
        results.append({
            'Model Name': cnn_name, 'RMSE': np.nan, 'MAE': np.nan, 'R2': np.nan,
            'Notes': f'Failed: {e}'
        })


# ==============================================================================
# STEP 6: REPORTING AND VISUALIZATION (Adjusted for display)
# ==============================================================================

if results:
    results_df = pd.DataFrame(results).sort_values(by='RMSE', ascending=True)

    print("\n" + "="*50)
    print("             MODEL PERFORMANCE SUMMARY")
    print("="*50)
    print(results_df.to_markdown(index=False))
    print("="*50)

    # Check if a best model was successfully trained
    if best_model_name and not np.isnan(best_rmse):
        print(f"🥇 Best Model: {best_model_name} (RMSE: {best_rmse:,.2f})")
    else:
        print("🚨 Warning: No models completed successfully or a new best model could not be determined.")

    print("="*50)
    print("\nDisplaying Final Summary Plots:")

    # 1. Plotting the performance of the best model (Actual vs. Predicted)
    if best_predictions is not None:
        plt.figure(figsize=(10, 6))
        plt.scatter(best_true_values, best_predictions, alpha=0.5)

        min_val = min(best_true_values.min(), best_predictions.min())
        max_val = max(best_true_values.max(), best_predictions.max())

        plt.plot([min_val, max_val], [min_val, max_val], 'r--')
        plt.xlabel("Actual Price (USD)")
        plt.ylabel("Predicted Price (USD)")
        plt.title(f"Actual vs. Predicted Prices for Best Model: {best_model_name}")
        plt.grid(True)
        plt.show() # Display the plot
        plt.close()
        print("\n✅ Displayed: Best Model Actual vs. Predicted Plot")

    # 2. Plotting all model RMSEs
    plt.figure(figsize=(12, 6))
    valid_results = results_df.dropna(subset=['RMSE'])
    plt.bar(valid_results['Model Name'], valid_results['RMSE'], color='skyblue')
    plt.xticks(rotation=45, ha='right')
    plt.ylabel("Root Mean Squared Error (RMSE)")
    plt.title("Comparison of Model Performance (RMSE)")
    plt.tight_layout()
    plt.show() # Display the plot
    plt.close()
    print("✅ Displayed: All Model RMSE Comparison Plot")

    # 3. Plotting Training History (Loss) of the Best Model
    if best_history is not None:
        plt.figure(figsize=(8, 5))
        # Note: The loss here is the scaled Huber loss, but still shows learning trend
        plt.plot(best_history.history['loss'], label='Train Loss (Scaled Huber)')
        plt.plot(best_history.history['val_loss'], label='Validation Loss (Scaled Huber)')
        plt.title(f'{best_model_name} Training History (Log-Scaled Huber Loss)')
        plt.xlabel('Epoch')
        plt.ylabel('Loss (Huber)')
        plt.legend()
        plt.grid(True)
        plt.show() # Display the plot
        plt.close()
        print("✅ Displayed: Best Model Training History Plot")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Configuration Complete. Image size: 128x128. Epochs: 30, LR: 0.0005
#
# Loading CSV data and preparing tabular features...
# Tabular data shape after preprocessing: (1591, 104)
#
# ✅ Target variable 'price' has been Log-Transformed and Standard Scaled for maximum stability.
# Found image directory at /content/gdrive/MyDrive/Deep Learning/images.
#
# Preparing image data with masking strategy...
# Loading Images and Creating Masks: 100%|██████████| 1591/1591 [00:12<00:00, 129.43it/s]
# Total records processed: 1591. Records with images: 466
# Image data shape: (1591, 128, 128, 3). Mask shape: (1591,)
#
# Training samples: 1272, Test samples: 319
#
# Starting sequential training of the 20 CNN-backed models (Tuning: EPOCHS=30, LR=0.0005, Loss=Huber, Architecture=Late Fusion)...
#
# ================ Model 1/20: AlexNet ================
# Training AlexNet...
# Epoch 1/30
# 40/40 - 13s - 336ms/step - loss: 0.3525 - mae: 0.7019 - val_loss: 0.3193 - val_mae: 0.6667
# Epoch 2/30
# 40/40 - 1s - 26ms/step - loss: 0.3458 - mae: 0.6904 - val_loss: 0.3158 - val_mae: 0.6586
# Epoch 3/30
# 40/40 - 1s - 21ms/step - loss: 0.3394 - mae: 0.6799 - val_loss: 0.3033 - val_mae: 0.6323
# Epoch 4/30
# 40/40 - 1s - 20ms/step - loss: 0.3293 - mae: 0.6633 - val_loss: 0.2955 - val_mae: 0.6116
# Epoch 5/30
# 40/40 - 1s - 21ms/step - loss: 0.3240 - mae: 0.6548 - val_loss: 0.2915 - val_mae: 0.6014
# Epoch 6/30
# 40/40 - 1s - 21ms/step - loss: 0.3162 - mae: 0.6441 - val_loss: 0.2908 - val_mae: 0.5985
# Epoch 7/30
# 40/40 - 1s - 20ms/step - loss: 0.3134 - mae: 0.6381 - val_loss: 0.2912 - val_mae: 0.5956
# Epoch 8/30
# 40/40 - 1s - 21ms/step - loss: 0.3097 - mae: 0.6313 - val_loss: 0.2908 - val_mae: 0.5958
# Epoch 9/30
# 40/40 - 1s - 21ms/step - loss: 0.3103 - mae: 0.6343 - val_loss: 0.2879 - val_mae: 0.5952
# Epoch 10/30
# 40/40 - 1s - 21ms/step - loss: 0.3076 - mae: 0.6256 - val_loss: 0.2886 - val_mae: 0.5935
# Epoch 11/30
# 40/40 - 1s - 21ms/step - loss: 0.3062 - mae: 0.6269 - val_loss: 0.2902 - val_mae: 0.5957
# Epoch 12/30
# 40/40 - 1s - 21ms/step - loss: 0.3053 - mae: 0.6195 - val_loss: 0.2869 - val_mae: 0.5953
# Epoch 13/30
# 40/40 - 1s - 25ms/step - loss: 0.3046 - mae: 0.6244 - val_loss: 0.2868 - val_mae: 0.5928
# Epoch 14/30
# 40/40 - 1s - 23ms/step - loss: 0.3006 - mae: 0.6146 - val_loss: 0.2894 - val_mae: 0.5977
# Epoch 15/30
# 40/40 - 1s - 24ms/step - loss: 0.2994 - mae: 0.6162 - val_loss: 0.2895 - val_mae: 0.5981
# Epoch 16/30
# 40/40 - 1s - 22ms/step - loss: 0.3010 - mae: 0.6174 - val_loss: 0.2878 - val_mae: 0.5968
# Epoch 17/30
# 40/40 - 1s - 21ms/step - loss: 0.2997 - mae: 0.6151 - val_loss: 0.2876 - val_mae: 0.5978
# Epoch 18/30
# 40/40 - 1s - 21ms/step - loss: 0.2974 - mae: 0.6122 - val_loss: 0.2914 - val_mae: 0.6005
# Epoch 19/30
# 40/40 - 1s - 21ms/step - loss: 0.2953 - mae: 0.6070 - val_loss: 0.2903 - val_mae: 0.6028
# Epoch 20/30
# 40/40 - 1s - 21ms/step - loss: 0.2950 - mae: 0.6079 - val_loss: 0.2899 - val_mae: 0.6027
# Epoch 21/30
# 40/40 - 1s - 21ms/step - loss: 0.2950 - mae: 0.6052 - val_loss: 0.2874 - val_mae: 0.5989
# Epoch 22/30
# 40/40 - 1s - 21ms/step - loss: 0.2913 - mae: 0.6003 - val_loss: 0.2852 - val_mae: 0.5916
# Epoch 23/30
# 40/40 - 1s - 31ms/step - loss: 0.2901 - mae: 0.5976 - val_loss: 0.2850 - val_mae: 0.5938
# Epoch 24/30
# 40/40 - 1s - 21ms/step - loss: 0.3001 - mae: 0.6135 - val_loss: 0.2861 - val_mae: 0.5954
# Epoch 25/30
# 40/40 - 1s - 21ms/step - loss: 0.2889 - mae: 0.6027 - val_loss: 0.2827 - val_mae: 0.5934
# Epoch 26/30
# 40/40 - 1s - 21ms/step - loss: 0.2873 - mae: 0.5940 - val_loss: 0.2808 - val_mae: 0.5915
# Epoch 27/30
# 40/40 - 1s - 21ms/step - loss: 0.2819 - mae: 0.5913 - val_loss: 0.2814 - val_mae: 0.5911
# Epoch 28/30
# 40/40 - 1s - 24ms/step - loss: 0.2870 - mae: 0.5985 - val_loss: 0.2845 - val_mae: 0.5983
# Epoch 29/30
# 40/40 - 1s - 32ms/step - loss: 0.2824 - mae: 0.5897 - val_loss: 0.2847 - val_mae: 0.5996
# Epoch 30/30
# 40/40 - 1s - 23ms/step - loss: 0.2819 - mae: 0.5863 - val_loss: 0.2809 - val_mae: 0.5917
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
#    Displaying Actual vs. Predicted plot for AlexNet...
# Training Complete. | *RMSE: 4,445,844.02* | MAE: 646,429.92 | R2: -0.0107
#
# ================ Model 2/20: NiN ================
# Training NiN...
# Epoch 1/30
# 40/40 - 15s - 373ms/step - loss: 0.3508 - mae: 0.6993 - val_loss: 0.3123 - val_mae: 0.6565
# Epoch 2/30
# 40/40 - 1s - 35ms/step - loss: 0.3472 - mae: 0.6917 - val_loss: 0.3078 - val_mae: 0.6469
# Epoch 3/30
# 40/40 - 1s - 33ms/step - loss: 0.3344 - mae: 0.6735 - val_loss: 0.2975 - val_mae: 0.6235
# Epoch 4/30
# 40/40 - 1s - 33ms/step - loss: 0.3282 - mae: 0.6646 - val_loss: 0.2986 - val_mae: 0.6214
# Epoch 5/30
# 40/40 - 1s - 33ms/step - loss: 0.3214 - mae: 0.6521 - val_loss: 0.2878 - val_mae: 0.6000
# Epoch 6/30
# 40/40 - 1s - 34ms/step - loss: 0.3212 - mae: 0.6512 - val_loss: 0.2880 - val_mae: 0.6024
# Epoch 7/30
# 40/40 - 1s - 36ms/step - loss: 0.3126 - mae: 0.6384 - val_loss: 0.2931 - val_mae: 0.6046
# Epoch 8/30
# 40/40 - 1s - 37ms/step - loss: 0.3081 - mae: 0.6310 - val_loss: 0.2872 - val_mae: 0.5976
# Epoch 9/30
# 40/40 - 1s - 33ms/step - loss: 0.3080 - mae: 0.6330 - val_loss: 0.2875 - val_mae: 0.5986
# Epoch 10/30
# 40/40 - 1s - 34ms/step - loss: 0.3060 - mae: 0.6280 - val_loss: 0.2856 - val_mae: 0.5945
# Epoch 11/30
# 40/40 - 1s - 34ms/step - loss: 0.3085 - mae: 0.6326 - val_loss: 0.2861 - val_mae: 0.5926
# Epoch 12/30
# 40/40 - 1s - 34ms/step - loss: 0.3030 - mae: 0.6228 - val_loss: 0.2832 - val_mae: 0.5901
# Epoch 13/30
# 40/40 - 1s - 33ms/step - loss: 0.3016 - mae: 0.6196 - val_loss: 0.2853 - val_mae: 0.5930
# Epoch 14/30
# 40/40 - 1s - 34ms/step - loss: 0.3014 - mae: 0.6188 - val_loss: 0.2838 - val_mae: 0.5916
# Epoch 15/30
# 40/40 - 1s - 34ms/step - loss: 0.2978 - mae: 0.6117 - val_loss: 0.2801 - val_mae: 0.5894
# Epoch 16/30
# 40/40 - 1s - 35ms/step - loss: 0.2907 - mae: 0.6039 - val_loss: 0.2812 - val_mae: 0.5899
# Epoch 17/30
# 40/40 - 3s - 63ms/step - loss: 0.2910 - mae: 0.6048 - val_loss: 0.2855 - val_mae: 0.6033
# Epoch 18/30
# 40/40 - 1s - 34ms/step - loss: 0.2890 - mae: 0.5986 - val_loss: 0.2793 - val_mae: 0.5937
# Epoch 19/30
# 40/40 - 1s - 34ms/step - loss: 0.2929 - mae: 0.6053 - val_loss: 0.2766 - val_mae: 0.5893
# Epoch 20/30
# 40/40 - 1s - 34ms/step - loss: 0.2867 - mae: 0.5964 - val_loss: 0.2799 - val_mae: 0.5861
# Epoch 21/30
# 40/40 - 1s - 34ms/step - loss: 0.2849 - mae: 0.5943 - val_loss: 0.2753 - val_mae: 0.5801
# Epoch 22/30
# 40/40 - 1s - 34ms/step - loss: 0.2866 - mae: 0.5954 - val_loss: 0.2805 - val_mae: 0.5997
# Epoch 23/30
# 40/40 - 2s - 42ms/step - loss: 0.2820 - mae: 0.5915 - val_loss: 0.2753 - val_mae: 0.5879
# Epoch 24/30
# 40/40 - 1s - 35ms/step - loss: 0.2812 - mae: 0.5876 - val_loss: 0.2762 - val_mae: 0.5857
# Epoch 25/30
# 40/40 - 1s - 36ms/step - loss: 0.2799 - mae: 0.5858 - val_loss: 0.2765 - val_mae: 0.5857
# Epoch 26/30
# 40/40 - 1s - 37ms/step - loss: 0.2808 - mae: 0.5888 - val_loss: 0.2727 - val_mae: 0.5796
# Epoch 27/30
# 40/40 - 1s - 33ms/step - loss: 0.2826 - mae: 0.5881 - val_loss: 0.2764 - val_mae: 0.5912
# Epoch 28/30
# 40/40 - 1s - 33ms/step - loss: 0.2762 - mae: 0.5785 - val_loss: 0.2729 - val_mae: 0.5820
# Epoch 29/30
# 40/40 - 1s - 33ms/step - loss: 0.2813 - mae: 0.5853 - val_loss: 0.2813 - val_mae: 0.5881
# Epoch 30/30
# 40/40 - 1s - 34ms/step - loss: 0.2791 - mae: 0.5821 - val_loss: 0.2739 - val_mae: 0.5865
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
#    Displaying Actual vs. Predicted plot for NiN...
# Training Complete. | *RMSE: 4,441,550.28* | MAE: 648,815.73 | R2: -0.0087
#
# ================ Model 3/20: ZNet ================
# Training ZNet...
# Epoch 1/30
# 40/40 - 12s - 289ms/step - loss: 0.3509 - mae: 0.6993 - val_loss: 0.3112 - val_mae: 0.6565
# Epoch 2/30
# 40/40 - 1s - 23ms/step - loss: 0.3427 - mae: 0.6897 - val_loss: 0.3070 - val_mae: 0.6462
# Epoch 3/30
# 40/40 - 1s - 21ms/step - loss: 0.3314 - mae: 0.6716 - val_loss: 0.3043 - val_mae: 0.6317
# Epoch 4/30
# 40/40 - 1s - 21ms/step - loss: 0.3278 - mae: 0.6630 - val_loss: 0.2945 - val_mae: 0.6126
# Epoch 5/30
# 40/40 - 1s - 21ms/step - loss: 0.3199 - mae: 0.6517 - val_loss: 0.2956 - val_mae: 0.6119
# Epoch 6/30
# 40/40 - 1s - 24ms/step - loss: 0.3199 - mae: 0.6470 - val_loss: 0.2897 - val_mae: 0.6001
# Epoch 7/30
# 40/40 - 1s - 25ms/step - loss: 0.3162 - mae: 0.6419 - val_loss: 0.2838 - val_mae: 0.6001
# Epoch 8/30
# 40/40 - 1s - 31ms/step - loss: 0.3087 - mae: 0.6341 - val_loss: 0.2824 - val_mae: 0.5948
# Epoch 9/30
# 40/40 - 1s - 22ms/step - loss: 0.3050 - mae: 0.6231 - val_loss: 0.2785 - val_mae: 0.5901
# Epoch 10/30
# 40/40 - 1s - 21ms/step - loss: 0.3041 - mae: 0.6225 - val_loss: 0.2810 - val_mae: 0.5934
# Epoch 11/30
# 40/40 - 1s - 28ms/step - loss: 0.2969 - mae: 0.6137 - val_loss: 0.2813 - val_mae: 0.5898
# Epoch 12/30
# 40/40 - 1s - 32ms/step - loss: 0.2948 - mae: 0.6103 - val_loss: 0.2756 - val_mae: 0.5855
# Epoch 13/30
# 40/40 - 1s - 23ms/step - loss: 0.2923 - mae: 0.6043 - val_loss: 0.2776 - val_mae: 0.5935
# Epoch 14/30
# 40/40 - 1s - 21ms/step - loss: 0.2925 - mae: 0.6040 - val_loss: 0.2828 - val_mae: 0.5901
# Epoch 15/30
# 40/40 - 1s - 21ms/step - loss: 0.2956 - mae: 0.6118 - val_loss: 0.2743 - val_mae: 0.5864
# Epoch 16/30
# 40/40 - 1s - 21ms/step - loss: 0.2878 - mae: 0.5979 - val_loss: 0.2725 - val_mae: 0.5832
# Epoch 17/30
# 40/40 - 1s - 21ms/step - loss: 0.2850 - mae: 0.5971 - val_loss: 0.2762 - val_mae: 0.5831
# Epoch 18/30
# 40/40 - 1s - 21ms/step - loss: 0.2893 - mae: 0.6018 - val_loss: 0.2774 - val_mae: 0.5918
# Epoch 19/30
# 40/40 - 1s - 21ms/step - loss: 0.2886 - mae: 0.6036 - val_loss: 0.2766 - val_mae: 0.5849
# Epoch 20/30
# 40/40 - 1s - 24ms/step - loss: 0.2814 - mae: 0.5904 - val_loss: 0.2748 - val_mae: 0.5867
# Epoch 21/30
# 40/40 - 1s - 23ms/step - loss: 0.2873 - mae: 0.5951 - val_loss: 0.2807 - val_mae: 0.5985
# Epoch 22/30
# 40/40 - 1s - 24ms/step - loss: 0.2828 - mae: 0.5914 - val_loss: 0.2768 - val_mae: 0.5906
# Epoch 23/30
# 40/40 - 1s - 23ms/step - loss: 0.2870 - mae: 0.5979 - val_loss: 0.2770 - val_mae: 0.5974
# Epoch 24/30
# 40/40 - 1s - 21ms/step - loss: 0.2812 - mae: 0.5924 - val_loss: 0.2776 - val_mae: 0.5833
# Epoch 25/30
# 40/40 - 1s - 21ms/step - loss: 0.2801 - mae: 0.5830 - val_loss: 0.2780 - val_mae: 0.5990
# Epoch 26/30
# 40/40 - 1s - 21ms/step - loss: 0.2830 - mae: 0.5938 - val_loss: 0.2729 - val_mae: 0.5842
# Epoch 27/30
# 40/40 - 1s - 21ms/step - loss: 0.2806 - mae: 0.5870 - val_loss: 0.2719 - val_mae: 0.5820
# Epoch 28/30
# 40/40 - 1s - 21ms/step - loss: 0.2796 - mae: 0.5828 - val_loss: 0.2713 - val_mae: 0.5818
# Epoch 29/30
# 40/40 - 1s - 21ms/step - loss: 0.2767 - mae: 0.5813 - val_loss: 0.2732 - val_mae: 0.5877
# Epoch 30/30
# 40/40 - 1s - 21ms/step - loss: 0.2788 - mae: 0.5844 - val_loss: 0.2782 - val_mae: 0.5861
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
#    Displaying Actual vs. Predicted plot for ZNet...
# Training Complete. | *RMSE: 4,456,236.18* | MAE: 643,387.99 | R2: -0.0154
#
# ================ Model 4/20: VGG ================
# Training VGG...
# Epoch 1/30
# 40/40 - 18s - 459ms/step - loss: 0.3455 - mae: 0.6935 - val_loss: 0.3029 - val_mae: 0.6454
# Epoch 2/30
# 40/40 - 3s - 73ms/step - loss: 0.3272 - mae: 0.6667 - val_loss: 0.2911 - val_mae: 0.6213
# Epoch 3/30
# 40/40 - 3s - 73ms/step - loss: 0.3132 - mae: 0.6420 - val_loss: 0.2824 - val_mae: 0.6050
# Epoch 4/30
# 40/40 - 3s - 73ms/step - loss: 0.3049 - mae: 0.6273 - val_loss: 0.2866 - val_mae: 0.6043
# Epoch 5/30
# 40/40 - 3s - 75ms/step - loss: 0.2961 - mae: 0.6157 - val_loss: 0.2783 - val_mae: 0.5942
# Epoch 6/30
# 40/40 - 3s - 75ms/step - loss: 0.2923 - mae: 0.6093 - val_loss: 0.2814 - val_mae: 0.5907
# Epoch 7/30
# 40/40 - 3s - 74ms/step - loss: 0.2862 - mae: 0.6017 - val_loss: 0.2764 - val_mae: 0.5889
# Epoch 8/30
# 40/40 - 3s - 73ms/step - loss: 0.2866 - mae: 0.5986 - val_loss: 0.2784 - val_mae: 0.5912
# Epoch 9/30
# 40/40 - 3s - 74ms/step - loss: 0.2829 - mae: 0.5961 - val_loss: 0.2739 - val_mae: 0.5820
# Epoch 10/30
# 40/40 - 3s - 73ms/step - loss: 0.2760 - mae: 0.5884 - val_loss: 0.2758 - val_mae: 0.5835
# Epoch 11/30
# 40/40 - 3s - 72ms/step - loss: 0.2752 - mae: 0.5820 - val_loss: 0.2744 - val_mae: 0.5855
# Epoch 12/30
# 40/40 - 3s - 72ms/step - loss: 0.2689 - mae: 0.5772 - val_loss: 0.2803 - val_mae: 0.5938
# Epoch 13/30
# 40/40 - 3s - 72ms/step - loss: 0.2672 - mae: 0.5689 - val_loss: 0.2734 - val_mae: 0.5796
# Epoch 14/30
# 40/40 - 3s - 73ms/step - loss: 0.2616 - mae: 0.5606 - val_loss: 0.2783 - val_mae: 0.5828
# Epoch 15/30
# 40/40 - 5s - 128ms/step - loss: 0.2615 - mae: 0.5594 - val_loss: 0.2719 - val_mae: 0.5810
# Epoch 16/30
# 40/40 - 3s - 71ms/step - loss: 0.2550 - mae: 0.5508 - val_loss: 0.3030 - val_mae: 0.6263
# Epoch 17/30
# 40/40 - 3s - 72ms/step - loss: 0.2648 - mae: 0.5645 - val_loss: 0.2811 - val_mae: 0.5906
# Epoch 18/30
# 40/40 - 3s - 74ms/step - loss: 0.2511 - mae: 0.5450 - val_loss: 0.2755 - val_mae: 0.5855
# Epoch 19/30
# 40/40 - 3s - 71ms/step - loss: 0.2478 - mae: 0.5410 - val_loss: 0.2819 - val_mae: 0.6014
# Epoch 20/30
# 40/40 - 3s - 71ms/step - loss: 0.2458 - mae: 0.5333 - val_loss: 0.2771 - val_mae: 0.5900
# Epoch 21/30
# 40/40 - 3s - 72ms/step - loss: 0.2446 - mae: 0.5321 - val_loss: 0.2787 - val_mae: 0.5984
# Epoch 22/30
# 40/40 - 3s - 73ms/step - loss: 0.2387 - mae: 0.5237 - val_loss: 0.2831 - val_mae: 0.5962
# Epoch 23/30
# 40/40 - 3s - 73ms/step - loss: 0.2385 - mae: 0.5207 - val_loss: 0.2766 - val_mae: 0.5866
# Epoch 24/30
# 40/40 - 3s - 72ms/step - loss: 0.2366 - mae: 0.5136 - val_loss: 0.2812 - val_mae: 0.5989
# Epoch 25/30
# 40/40 - 3s - 72ms/step - loss: 0.2353 - mae: 0.5157 - val_loss: 0.2815 - val_mae: 0.5980
# Epoch 26/30
# 40/40 - 3s - 72ms/step - loss: 0.2303 - mae: 0.5065 - val_loss: 0.2917 - val_mae: 0.6108
# Epoch 27/30
# 40/40 - 3s - 75ms/step - loss: 0.2296 - mae: 0.5051 - val_loss: 0.2762 - val_mae: 0.5884
# Epoch 28/30
# 40/40 - 3s - 73ms/step - loss: 0.2358 - mae: 0.5203 - val_loss: 0.2771 - val_mae: 0.5882
# Epoch 29/30
# 40/40 - 3s - 72ms/step - loss: 0.2268 - mae: 0.5016 - val_loss: 0.2845 - val_mae: 0.5997
# Epoch 30/30
# 40/40 - 3s - 72ms/step - loss: 0.2292 - mae: 0.5076 - val_loss: 0.2917 - val_mae: 0.6140
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step
#    Displaying Actual vs. Predicted plot for VGG...
# Training Complete. | *RMSE: 4,469,537.12* | MAE: 710,168.12 | R2: -0.0215
#
# ================ Model 5/20: Google LeNet ================
# Training Google LeNet...
# Epoch 1/30
# 40/40 - 10s - 255ms/step - loss: 0.3515 - mae: 0.7001 - val_loss: 0.3104 - val_mae: 0.6550
# Epoch 2/30
# 40/40 - 1s - 13ms/step - loss: 0.3464 - mae: 0.6921 - val_loss: 0.3079 - val_mae: 0.6495
# Epoch 3/30
# 40/40 - 0s - 12ms/step - loss: 0.3344 - mae: 0.6771 - val_loss: 0.3042 - val_mae: 0.6312
# Epoch 4/30
# 40/40 - 1s - 17ms/step - loss: 0.3314 - mae: 0.6692 - val_loss: 0.2908 - val_mae: 0.6052
# Epoch 5/30
# 40/40 - 1s - 15ms/step - loss: 0.3242 - mae: 0.6565 - val_loss: 0.2935 - val_mae: 0.6096
# Epoch 6/30
# 40/40 - 1s - 15ms/step - loss: 0.3190 - mae: 0.6500 - val_loss: 0.2891 - val_mae: 0.6039
# Epoch 7/30
# 40/40 - 1s - 16ms/step - loss: 0.3208 - mae: 0.6467 - val_loss: 0.2881 - val_mae: 0.6012
# Epoch 8/30
# 40/40 - 1s - 16ms/step - loss: 0.3150 - mae: 0.6425 - val_loss: 0.2886 - val_mae: 0.6012
# Epoch 9/30
# 40/40 - 1s - 14ms/step - loss: 0.3120 - mae: 0.6359 - val_loss: 0.2894 - val_mae: 0.6051
# Epoch 10/30
# 40/40 - 0s - 12ms/step - loss: 0.3097 - mae: 0.6310 - val_loss: 0.2871 - val_mae: 0.6011
# Epoch 11/30
# 40/40 - 0s - 12ms/step - loss: 0.3057 - mae: 0.6280 - val_loss: 0.2884 - val_mae: 0.6009
# Epoch 12/30
# 40/40 - 0s - 12ms/step - loss: 0.3070 - mae: 0.6273 - val_loss: 0.2879 - val_mae: 0.5972
# Epoch 13/30
# 40/40 - 0s - 12ms/step - loss: 0.3024 - mae: 0.6219 - val_loss: 0.2886 - val_mae: 0.6017
# Epoch 14/30
# 40/40 - 1s - 15ms/step - loss: 0.3059 - mae: 0.6240 - val_loss: 0.2863 - val_mae: 0.5971
# Epoch 15/30
# 40/40 - 1s - 14ms/step - loss: 0.2980 - mae: 0.6143 - val_loss: 0.2886 - val_mae: 0.6001
# Epoch 16/30
# 40/40 - 0s - 11ms/step - loss: 0.2988 - mae: 0.6166 - val_loss: 0.2886 - val_mae: 0.6024
# Epoch 17/30
# 40/40 - 0s - 12ms/step - loss: 0.2957 - mae: 0.6104 - val_loss: 0.2886 - val_mae: 0.6063
# Epoch 18/30
# 40/40 - 0s - 12ms/step - loss: 0.2991 - mae: 0.6170 - val_loss: 0.2837 - val_mae: 0.5952
# Epoch 19/30
# 40/40 - 0s - 12ms/step - loss: 0.2941 - mae: 0.6086 - val_loss: 0.2867 - val_mae: 0.6039
# Epoch 20/30
# 40/40 - 0s - 12ms/step - loss: 0.2948 - mae: 0.6101 - val_loss: 0.2841 - val_mae: 0.5969
# Epoch 21/30
# 40/40 - 0s - 12ms/step - loss: 0.2891 - mae: 0.5997 - val_loss: 0.2831 - val_mae: 0.5935
# Epoch 22/30
# 40/40 - 0s - 12ms/step - loss: 0.2904 - mae: 0.6019 - val_loss: 0.2838 - val_mae: 0.5999
# Epoch 23/30
# 40/40 - 0s - 12ms/step - loss: 0.2885 - mae: 0.6003 - val_loss: 0.2844 - val_mae: 0.5959
# Epoch 24/30
# 40/40 - 0s - 12ms/step - loss: 0.2907 - mae: 0.6056 - val_loss: 0.2835 - val_mae: 0.5968
# Epoch 25/30
# 40/40 - 0s - 12ms/step - loss: 0.2877 - mae: 0.5979 - val_loss: 0.2822 - val_mae: 0.5934
# Epoch 26/30
# 40/40 - 0s - 11ms/step - loss: 0.2871 - mae: 0.5975 - val_loss: 0.2841 - val_mae: 0.6007
# Epoch 27/30
# 40/40 - 0s - 12ms/step - loss: 0.2882 - mae: 0.5971 - val_loss: 0.2854 - val_mae: 0.5966
# Epoch 28/30
# 40/40 - 0s - 12ms/step - loss: 0.2869 - mae: 0.5951 - val_loss: 0.2864 - val_mae: 0.5988
# Epoch 29/30
# 40/40 - 0s - 12ms/step - loss: 0.2856 - mae: 0.5939 - val_loss: 0.2811 - val_mae: 0.5954
# Epoch 30/30
# 40/40 - 1s - 14ms/step - loss: 0.2889 - mae: 0.5997 - val_loss: 0.2829 - val_mae: 0.5950
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
#    Displaying Actual vs. Predicted plot for Google LeNet...
# Training Complete. | *RMSE: 4,446,548.03* | MAE: 644,306.74 | R2: -0.0110
#
# ================ Model 6/20: InceptionV3 ================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training InceptionV3...
# Epoch 1/30
# 40/40 - 42s - 1s/step - loss: 0.3453 - mae: 0.6932 - val_loss: 0.3133 - val_mae: 0.6583
# Epoch 2/30
# 40/40 - 1s - 33ms/step - loss: 0.3226 - mae: 0.6594 - val_loss: 0.3011 - val_mae: 0.6397
# Epoch 3/30
# 40/40 - 1s - 30ms/step - loss: 0.3024 - mae: 0.6293 - val_loss: 0.2951 - val_mae: 0.6219
# Epoch 4/30
# 40/40 - 1s - 30ms/step - loss: 0.2853 - mae: 0.6010 - val_loss: 0.2919 - val_mae: 0.6119
# Epoch 5/30
# 40/40 - 1s - 30ms/step - loss: 0.2716 - mae: 0.5834 - val_loss: 0.3138 - val_mae: 0.6406
# Epoch 6/30
# 40/40 - 1s - 34ms/step - loss: 0.2686 - mae: 0.5746 - val_loss: 0.2923 - val_mae: 0.6095
# Epoch 7/30
# 40/40 - 1s - 34ms/step - loss: 0.2580 - mae: 0.5580 - val_loss: 0.3024 - val_mae: 0.6159
# Epoch 8/30
# 40/40 - 1s - 34ms/step - loss: 0.2483 - mae: 0.5379 - val_loss: 0.2941 - val_mae: 0.6077
# Epoch 9/30
# 40/40 - 1s - 30ms/step - loss: 0.2383 - mae: 0.5222 - val_loss: 0.3028 - val_mae: 0.6242
# Epoch 10/30
# 40/40 - 1s - 30ms/step - loss: 0.2342 - mae: 0.5192 - val_loss: 0.3126 - val_mae: 0.6328
# Epoch 11/30
# 40/40 - 1s - 32ms/step - loss: 0.2301 - mae: 0.5132 - val_loss: 0.3147 - val_mae: 0.6318
# Epoch 12/30
# 40/40 - 1s - 31ms/step - loss: 0.2310 - mae: 0.5180 - val_loss: 0.3090 - val_mae: 0.6286
# Epoch 13/30
# 40/40 - 1s - 30ms/step - loss: 0.2211 - mae: 0.5037 - val_loss: 0.3186 - val_mae: 0.6309
# Epoch 14/30
# 40/40 - 1s - 30ms/step - loss: 0.2213 - mae: 0.4986 - val_loss: 0.3051 - val_mae: 0.6162
# Epoch 15/30
# 40/40 - 1s - 30ms/step - loss: 0.2180 - mae: 0.4941 - val_loss: 0.3086 - val_mae: 0.6246
# Epoch 16/30
# 40/40 - 1s - 31ms/step - loss: 0.2168 - mae: 0.4918 - val_loss: 0.3082 - val_mae: 0.6221
# Epoch 17/30
# 40/40 - 1s - 34ms/step - loss: 0.2177 - mae: 0.4899 - val_loss: 0.3036 - val_mae: 0.6157
# Epoch 18/30
# 40/40 - 1s - 35ms/step - loss: 0.2171 - mae: 0.4907 - val_loss: 0.3028 - val_mae: 0.6110
# Epoch 19/30
# 40/40 - 1s - 32ms/step - loss: 0.2120 - mae: 0.4841 - val_loss: 0.3113 - val_mae: 0.6261
# Epoch 20/30
# 40/40 - 1s - 30ms/step - loss: 0.2146 - mae: 0.4820 - val_loss: 0.3088 - val_mae: 0.6188
# Epoch 21/30
# 40/40 - 1s - 30ms/step - loss: 0.2059 - mae: 0.4689 - val_loss: 0.3112 - val_mae: 0.6262
# Epoch 22/30
# 40/40 - 1s - 32ms/step - loss: 0.2059 - mae: 0.4656 - val_loss: 0.3131 - val_mae: 0.6279
# Epoch 23/30
# 40/40 - 1s - 30ms/step - loss: 0.2075 - mae: 0.4724 - val_loss: 0.3017 - val_mae: 0.6110
# Epoch 24/30
# 40/40 - 1s - 30ms/step - loss: 0.2046 - mae: 0.4707 - val_loss: 0.3094 - val_mae: 0.6223
# Epoch 25/30
# 40/40 - 1s - 30ms/step - loss: 0.2047 - mae: 0.4710 - val_loss: 0.3070 - val_mae: 0.6235
# Epoch 26/30
# 40/40 - 1s - 30ms/step - loss: 0.2014 - mae: 0.4615 - val_loss: 0.3053 - val_mae: 0.6164
# Epoch 27/30
# 40/40 - 1s - 32ms/step - loss: 0.2065 - mae: 0.4673 - val_loss: 0.3127 - val_mae: 0.6267
# Epoch 28/30
# 40/40 - 1s - 34ms/step - loss: 0.2026 - mae: 0.4655 - val_loss: 0.3122 - val_mae: 0.6254
# Epoch 29/30
# 40/40 - 1s - 36ms/step - loss: 0.2010 - mae: 0.4615 - val_loss: 0.3033 - val_mae: 0.6129
# Epoch 30/30
# 40/40 - 1s - 30ms/step - loss: 0.2016 - mae: 0.4572 - val_loss: 0.3181 - val_mae: 0.6336
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 794ms/step
#    Displaying Actual vs. Predicted plot for InceptionV3...
# Training Complete. | *RMSE: 4,667,968.98* | MAE: 768,856.19 | R2: -0.1142
#
# ================ Model 7/20: Highway ================
# Training Highway...
# Epoch 1/30
# 40/40 - 9s - 226ms/step - loss: 0.3513 - mae: 0.6999 - val_loss: 0.3102 - val_mae: 0.6523
# Epoch 2/30
# 40/40 - 1s - 14ms/step - loss: 0.3412 - mae: 0.6849 - val_loss: 0.3028 - val_mae: 0.6355
# Epoch 3/30
# 40/40 - 1s - 14ms/step - loss: 0.3307 - mae: 0.6688 - val_loss: 0.2940 - val_mae: 0.6112
# Epoch 4/30
# 40/40 - 1s - 17ms/step - loss: 0.3239 - mae: 0.6601 - val_loss: 0.2904 - val_mae: 0.6011
# Epoch 5/30
# 40/40 - 1s - 13ms/step - loss: 0.3247 - mae: 0.6551 - val_loss: 0.2911 - val_mae: 0.6021
# Epoch 6/30
# 40/40 - 0s - 12ms/step - loss: 0.3163 - mae: 0.6472 - val_loss: 0.2926 - val_mae: 0.6024
# Epoch 7/30
# 40/40 - 0s - 10ms/step - loss: 0.3199 - mae: 0.6510 - val_loss: 0.2898 - val_mae: 0.5982
# Epoch 8/30
# 40/40 - 0s - 10ms/step - loss: 0.3174 - mae: 0.6405 - val_loss: 0.2874 - val_mae: 0.5948
# Epoch 9/30
# 40/40 - 0s - 10ms/step - loss: 0.3158 - mae: 0.6423 - val_loss: 0.2877 - val_mae: 0.5931
# Epoch 10/30
# 40/40 - 0s - 10ms/step - loss: 0.3111 - mae: 0.6325 - val_loss: 0.2885 - val_mae: 0.5972
# Epoch 11/30
# 40/40 - 0s - 10ms/step - loss: 0.3046 - mae: 0.6247 - val_loss: 0.2875 - val_mae: 0.5932
# Epoch 12/30
# 40/40 - 0s - 10ms/step - loss: 0.3056 - mae: 0.6227 - val_loss: 0.2864 - val_mae: 0.5937
# Epoch 13/30
# 40/40 - 0s - 11ms/step - loss: 0.3009 - mae: 0.6184 - val_loss: 0.2867 - val_mae: 0.5924
# Epoch 14/30
# 40/40 - 0s - 10ms/step - loss: 0.3034 - mae: 0.6208 - val_loss: 0.2874 - val_mae: 0.5952
# Epoch 15/30
# 40/40 - 0s - 10ms/step - loss: 0.2977 - mae: 0.6152 - val_loss: 0.2868 - val_mae: 0.5952
# Epoch 16/30
# 40/40 - 0s - 12ms/step - loss: 0.2983 - mae: 0.6136 - val_loss: 0.2872 - val_mae: 0.5946
# Epoch 17/30
# 40/40 - 0s - 10ms/step - loss: 0.2925 - mae: 0.6061 - val_loss: 0.2862 - val_mae: 0.5945
# Epoch 18/30
# 40/40 - 0s - 10ms/step - loss: 0.2946 - mae: 0.6064 - val_loss: 0.2874 - val_mae: 0.5953
# Epoch 19/30
# 40/40 - 0s - 10ms/step - loss: 0.3009 - mae: 0.6154 - val_loss: 0.2853 - val_mae: 0.5940
# Epoch 20/30
# 40/40 - 0s - 10ms/step - loss: 0.2928 - mae: 0.6041 - val_loss: 0.2874 - val_mae: 0.6004
# Epoch 21/30
# 40/40 - 0s - 10ms/step - loss: 0.2945 - mae: 0.6086 - val_loss: 0.2863 - val_mae: 0.5967
# Epoch 22/30
# 40/40 - 0s - 12ms/step - loss: 0.2902 - mae: 0.6005 - val_loss: 0.2925 - val_mae: 0.6018
# Epoch 23/30
# 40/40 - 0s - 10ms/step - loss: 0.2965 - mae: 0.6087 - val_loss: 0.2849 - val_mae: 0.5939
# Epoch 24/30
# 40/40 - 0s - 10ms/step - loss: 0.2902 - mae: 0.6038 - val_loss: 0.2855 - val_mae: 0.5983
# Epoch 25/30
# 40/40 - 0s - 10ms/step - loss: 0.2918 - mae: 0.6036 - val_loss: 0.2849 - val_mae: 0.5932
# Epoch 26/30
# 40/40 - 0s - 10ms/step - loss: 0.2874 - mae: 0.5975 - val_loss: 0.2891 - val_mae: 0.5968
# Epoch 27/30
# 40/40 - 0s - 10ms/step - loss: 0.2879 - mae: 0.5977 - val_loss: 0.2865 - val_mae: 0.5995
# Epoch 28/30
# 40/40 - 0s - 10ms/step - loss: 0.2874 - mae: 0.5967 - val_loss: 0.2851 - val_mae: 0.5959
# Epoch 29/30
# 40/40 - 1s - 13ms/step - loss: 0.2859 - mae: 0.5940 - val_loss: 0.2839 - val_mae: 0.5942
# Epoch 30/30
# 40/40 - 1s - 16ms/step - loss: 0.2849 - mae: 0.5952 - val_loss: 0.2836 - val_mae: 0.5953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
#    Displaying Actual vs. Predicted plot for Highway...
# Training Complete. | *RMSE: 4,439,928.20* | MAE: 648,318.86 | R2: -0.0080
#
# ================ Model 8/20: InceptionV4 ================
# Training InceptionV4...
# Epoch 1/30
# 40/40 - 9s - 215ms/step - loss: 0.3510 - mae: 0.7004 - val_loss: 0.3114 - val_mae: 0.6562
# Epoch 2/30
# 40/40 - 0s - 11ms/step - loss: 0.3424 - mae: 0.6874 - val_loss: 0.3051 - val_mae: 0.6435
# Epoch 3/30
# 40/40 - 1s - 13ms/step - loss: 0.3330 - mae: 0.6709 - val_loss: 0.2947 - val_mae: 0.6139
# Epoch 4/30
# 40/40 - 1s - 14ms/step - loss: 0.3191 - mae: 0.6475 - val_loss: 0.2932 - val_mae: 0.6063
# Epoch 5/30
# 40/40 - 1s - 13ms/step - loss: 0.3212 - mae: 0.6476 - val_loss: 0.2922 - val_mae: 0.6056
# Epoch 6/30
# 40/40 - 1s - 15ms/step - loss: 0.3144 - mae: 0.6406 - val_loss: 0.2884 - val_mae: 0.5961
# Epoch 7/30
# 40/40 - 1s - 14ms/step - loss: 0.3108 - mae: 0.6341 - val_loss: 0.2894 - val_mae: 0.5977
# Epoch 8/30
# 40/40 - 1s - 14ms/step - loss: 0.3121 - mae: 0.6379 - val_loss: 0.2854 - val_mae: 0.5921
# Epoch 9/30
# 40/40 - 0s - 12ms/step - loss: 0.3009 - mae: 0.6176 - val_loss: 0.2865 - val_mae: 0.5947
# Epoch 10/30
# 40/40 - 0s - 12ms/step - loss: 0.3027 - mae: 0.6201 - val_loss: 0.2849 - val_mae: 0.5933
# Epoch 11/30
# 40/40 - 0s - 10ms/step - loss: 0.3039 - mae: 0.6221 - val_loss: 0.2848 - val_mae: 0.5920
# Epoch 12/30
# 40/40 - 0s - 11ms/step - loss: 0.2996 - mae: 0.6166 - val_loss: 0.2849 - val_mae: 0.5904
# Epoch 13/30
# 40/40 - 0s - 10ms/step - loss: 0.3024 - mae: 0.6204 - val_loss: 0.2861 - val_mae: 0.5940
# Epoch 14/30
# 40/40 - 0s - 11ms/step - loss: 0.2980 - mae: 0.6123 - val_loss: 0.2870 - val_mae: 0.5958
# Epoch 15/30
# 40/40 - 0s - 10ms/step - loss: 0.2997 - mae: 0.6127 - val_loss: 0.2833 - val_mae: 0.5945
# Epoch 16/30
# 40/40 - 0s - 10ms/step - loss: 0.2943 - mae: 0.6063 - val_loss: 0.2831 - val_mae: 0.5957
# Epoch 17/30
# 40/40 - 0s - 10ms/step - loss: 0.2954 - mae: 0.6092 - val_loss: 0.2834 - val_mae: 0.5958
# Epoch 18/30
# 40/40 - 0s - 12ms/step - loss: 0.2968 - mae: 0.6108 - val_loss: 0.2812 - val_mae: 0.5905
# Epoch 19/30
# 40/40 - 1s - 14ms/step - loss: 0.2949 - mae: 0.6065 - val_loss: 0.2832 - val_mae: 0.5920
# Epoch 20/30
# 40/40 - 0s - 10ms/step - loss: 0.2949 - mae: 0.6073 - val_loss: 0.2839 - val_mae: 0.5924
# Epoch 21/30
# 40/40 - 0s - 10ms/step - loss: 0.2933 - mae: 0.6058 - val_loss: 0.2818 - val_mae: 0.5921
# Epoch 22/30
# 40/40 - 0s - 10ms/step - loss: 0.2903 - mae: 0.6004 - val_loss: 0.2821 - val_mae: 0.5905
# Epoch 23/30
# 40/40 - 0s - 10ms/step - loss: 0.2904 - mae: 0.6016 - val_loss: 0.2834 - val_mae: 0.5926
# Epoch 24/30
# 40/40 - 1s - 17ms/step - loss: 0.2898 - mae: 0.5968 - val_loss: 0.2806 - val_mae: 0.5920
# Epoch 25/30
# 40/40 - 0s - 11ms/step - loss: 0.2850 - mae: 0.5935 - val_loss: 0.2829 - val_mae: 0.5935
# Epoch 26/30
# 40/40 - 0s - 12ms/step - loss: 0.2884 - mae: 0.5984 - val_loss: 0.2867 - val_mae: 0.5966
# Epoch 27/30
# 40/40 - 0s - 10ms/step - loss: 0.2919 - mae: 0.5996 - val_loss: 0.2891 - val_mae: 0.6012
# Epoch 28/30
# 40/40 - 0s - 10ms/step - loss: 0.2854 - mae: 0.5942 - val_loss: 0.2885 - val_mae: 0.6015
# Epoch 29/30
# 40/40 - 0s - 10ms/step - loss: 0.2849 - mae: 0.5949 - val_loss: 0.2812 - val_mae: 0.5926
# Epoch 30/30
# 40/40 - 0s - 10ms/step - loss: 0.2812 - mae: 0.5866 - val_loss: 0.2839 - val_mae: 0.5963
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
#    Displaying Actual vs. Predicted plot for InceptionV4...
# Training Complete. | *RMSE: 4,447,951.34* | MAE: 648,125.96 | R2: -0.0116
#
# ================ Model 9/20: ResNet ================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training ResNet...
# Epoch 1/30
# 40/40 - 30s - 739ms/step - loss: 0.3490 - mae: 0.7001 - val_loss: 0.3120 - val_mae: 0.6575
# Epoch 2/30
# 40/40 - 2s - 38ms/step - loss: 0.3444 - mae: 0.6898 - val_loss: 0.3073 - val_mae: 0.6478
# Epoch 3/30
# 40/40 - 2s - 39ms/step - loss: 0.3365 - mae: 0.6780 - val_loss: 0.2990 - val_mae: 0.6302
# Epoch 4/30
# 40/40 - 2s - 39ms/step - loss: 0.3311 - mae: 0.6659 - val_loss: 0.2908 - val_mae: 0.6117
# Epoch 5/30
# 40/40 - 2s - 40ms/step - loss: 0.3248 - mae: 0.6577 - val_loss: 0.2905 - val_mae: 0.6062
# Epoch 6/30
# 40/40 - 2s - 42ms/step - loss: 0.3145 - mae: 0.6440 - val_loss: 0.2916 - val_mae: 0.6037
# Epoch 7/30
# 40/40 - 2s - 43ms/step - loss: 0.3180 - mae: 0.6439 - val_loss: 0.2862 - val_mae: 0.6013
# Epoch 8/30
# 40/40 - 2s - 40ms/step - loss: 0.3150 - mae: 0.6378 - val_loss: 0.2885 - val_mae: 0.5988
# Epoch 9/30
# 40/40 - 2s - 39ms/step - loss: 0.3050 - mae: 0.6305 - val_loss: 0.2899 - val_mae: 0.5975
# Epoch 10/30
# 40/40 - 2s - 40ms/step - loss: 0.3033 - mae: 0.6208 - val_loss: 0.2855 - val_mae: 0.5964
# Epoch 11/30
# 40/40 - 2s - 40ms/step - loss: 0.3010 - mae: 0.6217 - val_loss: 0.2851 - val_mae: 0.5930
# Epoch 12/30
# 40/40 - 2s - 40ms/step - loss: 0.2960 - mae: 0.6139 - val_loss: 0.2840 - val_mae: 0.6008
# Epoch 13/30
# 40/40 - 2s - 40ms/step - loss: 0.2940 - mae: 0.6100 - val_loss: 0.2825 - val_mae: 0.5931
# Epoch 14/30
# 40/40 - 2s - 43ms/step - loss: 0.2988 - mae: 0.6137 - val_loss: 0.2797 - val_mae: 0.5896
# Epoch 15/30
# 40/40 - 2s - 44ms/step - loss: 0.2930 - mae: 0.6049 - val_loss: 0.2815 - val_mae: 0.5948
# Epoch 16/30
# 40/40 - 2s - 59ms/step - loss: 0.2911 - mae: 0.6051 - val_loss: 0.2819 - val_mae: 0.5912
# Epoch 17/30
# 40/40 - 2s - 40ms/step - loss: 0.2915 - mae: 0.6027 - val_loss: 0.2800 - val_mae: 0.5916
# Epoch 18/30
# 40/40 - 3s - 64ms/step - loss: 0.2879 - mae: 0.5989 - val_loss: 0.2785 - val_mae: 0.5888
# Epoch 19/30
# 40/40 - 2s - 40ms/step - loss: 0.2886 - mae: 0.5994 - val_loss: 0.2940 - val_mae: 0.6188
# Epoch 20/30
# 40/40 - 2s - 40ms/step - loss: 0.2887 - mae: 0.6001 - val_loss: 0.2826 - val_mae: 0.6010
# Epoch 21/30
# 40/40 - 2s - 43ms/step - loss: 0.2858 - mae: 0.5980 - val_loss: 0.2834 - val_mae: 0.6024
# Epoch 22/30
# 40/40 - 2s - 44ms/step - loss: 0.2846 - mae: 0.5921 - val_loss: 0.2898 - val_mae: 0.6126
# Epoch 23/30
# 40/40 - 2s - 40ms/step - loss: 0.2866 - mae: 0.5933 - val_loss: 0.2775 - val_mae: 0.5946
# Epoch 24/30
# 40/40 - 2s - 40ms/step - loss: 0.2828 - mae: 0.5920 - val_loss: 0.2781 - val_mae: 0.5906
# Epoch 25/30
# 40/40 - 2s - 39ms/step - loss: 0.2809 - mae: 0.5858 - val_loss: 0.2791 - val_mae: 0.5902
# Epoch 26/30
# 40/40 - 2s - 39ms/step - loss: 0.2791 - mae: 0.5824 - val_loss: 0.2882 - val_mae: 0.6008
# Epoch 27/30
# 40/40 - 2s - 39ms/step - loss: 0.2788 - mae: 0.5852 - val_loss: 0.2876 - val_mae: 0.6094
# Epoch 28/30
# 40/40 - 2s - 39ms/step - loss: 0.2797 - mae: 0.5861 - val_loss: 0.2819 - val_mae: 0.5916
# Epoch 29/30
# 40/40 - 2s - 49ms/step - loss: 0.2789 - mae: 0.5834 - val_loss: 0.2787 - val_mae: 0.5897
# Epoch 30/30
# 40/40 - 2s - 56ms/step - loss: 0.2763 - mae: 0.5775 - val_loss: 0.2810 - val_mae: 0.5921
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 440ms/step
#    Displaying Actual vs. Predicted plot for ResNet...
# Training Complete. | *RMSE: 4,448,379.26* | MAE: 646,609.58 | R2: -0.0118
#
# ================ Model 10/20: InceptionV4 ResNet ================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Training InceptionV4 ResNet...
# Epoch 1/30
# 40/40 - 67s - 2s/step - loss: 0.3509 - mae: 0.6984 - val_loss: 0.3042 - val_mae: 0.6430
# Epoch 2/30
# 40/40 - 3s - 66ms/step - loss: 0.3199 - mae: 0.6570 - val_loss: 0.3218 - val_mae: 0.6646
# Epoch 3/30
# 40/40 - 3s - 64ms/step - loss: 0.3107 - mae: 0.6447 - val_loss: 0.2987 - val_mae: 0.6302
# Epoch 4/30
# 40/40 - 3s - 69ms/step - loss: 0.2977 - mae: 0.6200 - val_loss: 0.2959 - val_mae: 0.6155
# Epoch 5/30
# 40/40 - 3s - 71ms/step - loss: 0.2871 - mae: 0.6029 - val_loss: 0.2985 - val_mae: 0.6190
# Epoch 6/30
# 40/40 - 3s - 65ms/step - loss: 0.2821 - mae: 0.5944 - val_loss: 0.2926 - val_mae: 0.6064
# Epoch 7/30
# 40/40 - 3s - 65ms/step - loss: 0.2739 - mae: 0.5837 - val_loss: 0.2994 - val_mae: 0.6198
# Epoch 8/30
# 40/40 - 3s - 66ms/step - loss: 0.2708 - mae: 0.5795 - val_loss: 0.2997 - val_mae: 0.6203
# Epoch 9/30
# 40/40 - 3s - 69ms/step - loss: 0.2615 - mae: 0.5625 - val_loss: 0.3077 - val_mae: 0.6299
# Epoch 10/30
# 40/40 - 3s - 70ms/step - loss: 0.2527 - mae: 0.5480 - val_loss: 0.2909 - val_mae: 0.6044
# Epoch 11/30
# 40/40 - 3s - 66ms/step - loss: 0.2510 - mae: 0.5475 - val_loss: 0.3009 - val_mae: 0.6175
# Epoch 12/30
# 40/40 - 3s - 66ms/step - loss: 0.2391 - mae: 0.5250 - val_loss: 0.3019 - val_mae: 0.6192
# Epoch 13/30
# 40/40 - 3s - 66ms/step - loss: 0.2401 - mae: 0.5305 - val_loss: 0.3044 - val_mae: 0.6189
# Epoch 14/30
# 40/40 - 3s - 73ms/step - loss: 0.2371 - mae: 0.5240 - val_loss: 0.3019 - val_mae: 0.6170
# Epoch 15/30
# 40/40 - 3s - 69ms/step - loss: 0.2363 - mae: 0.5259 - val_loss: 0.3087 - val_mae: 0.6274
# Epoch 16/30
# 40/40 - 3s - 66ms/step - loss: 0.2275 - mae: 0.5131 - val_loss: 0.2933 - val_mae: 0.6009
# Epoch 17/30
# 40/40 - 3s - 66ms/step - loss: 0.2296 - mae: 0.5118 - val_loss: 0.3035 - val_mae: 0.6253
# Epoch 18/30
# 40/40 - 3s - 66ms/step - loss: 0.2234 - mae: 0.5079 - val_loss: 0.3000 - val_mae: 0.6162
# Epoch 19/30
# 40/40 - 3s - 71ms/step - loss: 0.2185 - mae: 0.4956 - val_loss: 0.2985 - val_mae: 0.6131
# Epoch 20/30
# 40/40 - 3s - 68ms/step - loss: 0.2151 - mae: 0.4905 - val_loss: 0.2900 - val_mae: 0.6001
# Epoch 21/30
# 40/40 - 3s - 65ms/step - loss: 0.2181 - mae: 0.4902 - val_loss: 0.2998 - val_mae: 0.6146
# Epoch 22/30
# 40/40 - 3s - 65ms/step - loss: 0.2118 - mae: 0.4785 - val_loss: 0.2953 - val_mae: 0.6057
# Epoch 23/30
# 40/40 - 3s - 65ms/step - loss: 0.2128 - mae: 0.4833 - val_loss: 0.3053 - val_mae: 0.6233
# Epoch 24/30
# 40/40 - 3s - 73ms/step - loss: 0.2188 - mae: 0.4890 - val_loss: 0.2999 - val_mae: 0.6139
# Epoch 25/30
# 40/40 - 3s - 66ms/step - loss: 0.2097 - mae: 0.4764 - val_loss: 0.3147 - val_mae: 0.6406
# Epoch 26/30
# 40/40 - 3s - 65ms/step - loss: 0.2068 - mae: 0.4705 - val_loss: 0.3094 - val_mae: 0.6313
# Epoch 27/30
# 40/40 - 3s - 65ms/step - loss: 0.2055 - mae: 0.4679 - val_loss: 0.3155 - val_mae: 0.6393
# Epoch 28/30
# 40/40 - 3s - 65ms/step - loss: 0.2058 - mae: 0.4662 - val_loss: 0.3040 - val_mae: 0.6239
# Epoch 29/30
# 40/40 - 3s - 72ms/step - loss: 0.2073 - mae: 0.4739 - val_loss: 0.3100 - val_mae: 0.6327
# Epoch 30/30
# 40/40 - 3s - 66ms/step - loss: 0.2065 - mae: 0.4702 - val_loss: 0.3022 - val_mae: 0.6159
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step
#    Displaying Actual vs. Predicted plot for InceptionV4 ResNet...
# Training Complete. | *RMSE: 4,450,354.85* | MAE: 663,099.17 | R2: -0.0127
#
# ================ Model 11/20: FractalNet ================
# Training FractalNet...
# Epoch 1/30
# 40/40 - 9s - 227ms/step - loss: 0.3521 - mae: 0.7006 - val_loss: 0.3132 - val_mae: 0.6583
# Epoch 2/30
# 40/40 - 1s - 14ms/step - loss: 0.3452 - mae: 0.6909 - val_loss: 0.3088 - val_mae: 0.6502
# Epoch 3/30
# 40/40 - 1s - 14ms/step - loss: 0.3361 - mae: 0.6785 - val_loss: 0.2956 - val_mae: 0.6206
# Epoch 4/30
# 40/40 - 1s - 15ms/step - loss: 0.3276 - mae: 0.6649 - val_loss: 0.2917 - val_mae: 0.6054
# Epoch 5/30
# 40/40 - 1s - 15ms/step - loss: 0.3260 - mae: 0.6565 - val_loss: 0.2906 - val_mae: 0.6026
# Epoch 6/30
# 40/40 - 0s - 11ms/step - loss: 0.3160 - mae: 0.6464 - val_loss: 0.2920 - val_mae: 0.5999
# Epoch 7/30
# 40/40 - 0s - 11ms/step - loss: 0.3098 - mae: 0.6331 - val_loss: 0.2900 - val_mae: 0.5969
# Epoch 8/30
# 40/40 - 0s - 11ms/step - loss: 0.3147 - mae: 0.6395 - val_loss: 0.2892 - val_mae: 0.5968
# Epoch 9/30
# 40/40 - 0s - 11ms/step - loss: 0.3126 - mae: 0.6377 - val_loss: 0.2884 - val_mae: 0.5943
# Epoch 10/30
# 40/40 - 0s - 11ms/step - loss: 0.3051 - mae: 0.6249 - val_loss: 0.2901 - val_mae: 0.5970
# Epoch 11/30
# 40/40 - 0s - 12ms/step - loss: 0.3050 - mae: 0.6227 - val_loss: 0.2891 - val_mae: 0.5951
# Epoch 12/30
# 40/40 - 0s - 10ms/step - loss: 0.3025 - mae: 0.6206 - val_loss: 0.2883 - val_mae: 0.5968
# Epoch 13/30
# 40/40 - 0s - 10ms/step - loss: 0.3014 - mae: 0.6178 - val_loss: 0.2860 - val_mae: 0.5936
# Epoch 14/30
# 40/40 - 0s - 11ms/step - loss: 0.3009 - mae: 0.6191 - val_loss: 0.2856 - val_mae: 0.5905
# Epoch 15/30
# 40/40 - 0s - 10ms/step - loss: 0.3015 - mae: 0.6159 - val_loss: 0.2859 - val_mae: 0.5918
# Epoch 16/30
# 40/40 - 0s - 11ms/step - loss: 0.3005 - mae: 0.6150 - val_loss: 0.2851 - val_mae: 0.5917
# Epoch 17/30
# 40/40 - 0s - 10ms/step - loss: 0.3049 - mae: 0.6203 - val_loss: 0.2857 - val_mae: 0.5944
# Epoch 18/30
# 40/40 - 0s - 10ms/step - loss: 0.2997 - mae: 0.6128 - val_loss: 0.2861 - val_mae: 0.5958
# Epoch 19/30
# 40/40 - 0s - 11ms/step - loss: 0.2965 - mae: 0.6116 - val_loss: 0.2860 - val_mae: 0.5994
# Epoch 20/30
# 40/40 - 0s - 10ms/step - loss: 0.2931 - mae: 0.6068 - val_loss: 0.2839 - val_mae: 0.5924
# Epoch 21/30
# 40/40 - 0s - 10ms/step - loss: 0.2970 - mae: 0.6106 - val_loss: 0.2826 - val_mae: 0.5922
# Epoch 22/30
# 40/40 - 0s - 10ms/step - loss: 0.2902 - mae: 0.6025 - val_loss: 0.2852 - val_mae: 0.5976
# Epoch 23/30
# 40/40 - 0s - 10ms/step - loss: 0.2910 - mae: 0.6020 - val_loss: 0.2855 - val_mae: 0.5983
# Epoch 24/30
# 40/40 - 0s - 10ms/step - loss: 0.2899 - mae: 0.5997 - val_loss: 0.2835 - val_mae: 0.5926
# Epoch 25/30
# 40/40 - 0s - 10ms/step - loss: 0.2892 - mae: 0.6001 - val_loss: 0.2827 - val_mae: 0.5920
# Epoch 26/30
# 40/40 - 0s - 10ms/step - loss: 0.2874 - mae: 0.5940 - val_loss: 0.2816 - val_mae: 0.5884
# Epoch 27/30
# 40/40 - 0s - 11ms/step - loss: 0.2900 - mae: 0.6012 - val_loss: 0.2801 - val_mae: 0.5871
# Epoch 28/30
# 40/40 - 0s - 11ms/step - loss: 0.2864 - mae: 0.5901 - val_loss: 0.2802 - val_mae: 0.5863
# Epoch 29/30
# 40/40 - 1s - 14ms/step - loss: 0.2854 - mae: 0.5971 - val_loss: 0.2861 - val_mae: 0.5959
# Epoch 30/30
# 40/40 - 1s - 15ms/step - loss: 0.2849 - mae: 0.5933 - val_loss: 0.2831 - val_mae: 0.5914
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
#    Displaying Actual vs. Predicted plot for FractalNet...
# Training Complete. | *RMSE: 4,438,018.55* | MAE: 647,852.88 | R2: -0.0071
#
# ================ Model 12/20: WideResNet ================
# Training WideResNet...
# Epoch 1/30
# 40/40 - 9s - 214ms/step - loss: 0.3511 - mae: 0.6999 - val_loss: 0.3132 - val_mae: 0.6575
# Epoch 2/30
# 40/40 - 1s - 14ms/step - loss: 0.3453 - mae: 0.6904 - val_loss: 0.3075 - val_mae: 0.6468
# Epoch 3/30
# 40/40 - 1s - 13ms/step - loss: 0.3368 - mae: 0.6780 - val_loss: 0.3023 - val_mae: 0.6322
# Epoch 4/30
# 40/40 - 1s - 13ms/step - loss: 0.3311 - mae: 0.6699 - val_loss: 0.2981 - val_mae: 0.6213
# Epoch 5/30
# 40/40 - 1s - 13ms/step - loss: 0.3221 - mae: 0.6552 - val_loss: 0.2938 - val_mae: 0.6048
# Epoch 6/30
# 40/40 - 1s - 15ms/step - loss: 0.3193 - mae: 0.6446 - val_loss: 0.2919 - val_mae: 0.6032
# Epoch 7/30
# 40/40 - 1s - 15ms/step - loss: 0.3144 - mae: 0.6409 - val_loss: 0.2922 - val_mae: 0.6019
# Epoch 8/30
# 40/40 - 0s - 12ms/step - loss: 0.3116 - mae: 0.6358 - val_loss: 0.2902 - val_mae: 0.5970
# Epoch 9/30
# 40/40 - 0s - 11ms/step - loss: 0.3095 - mae: 0.6324 - val_loss: 0.2903 - val_mae: 0.5991
# Epoch 10/30
# 40/40 - 0s - 11ms/step - loss: 0.3075 - mae: 0.6266 - val_loss: 0.2888 - val_mae: 0.5943
# Epoch 11/30
# 40/40 - 0s - 11ms/step - loss: 0.3061 - mae: 0.6260 - val_loss: 0.2868 - val_mae: 0.5929
# Epoch 12/30
# 40/40 - 0s - 11ms/step - loss: 0.2987 - mae: 0.6154 - val_loss: 0.2840 - val_mae: 0.5901
# Epoch 13/30
# 40/40 - 0s - 11ms/step - loss: 0.3029 - mae: 0.6168 - val_loss: 0.2851 - val_mae: 0.5926
# Epoch 14/30
# 40/40 - 0s - 10ms/step - loss: 0.3055 - mae: 0.6222 - val_loss: 0.2852 - val_mae: 0.5914
# Epoch 15/30
# 40/40 - 1s - 15ms/step - loss: 0.2981 - mae: 0.6099 - val_loss: 0.2841 - val_mae: 0.5917
# Epoch 16/30
# 40/40 - 0s - 10ms/step - loss: 0.3002 - mae: 0.6156 - val_loss: 0.2841 - val_mae: 0.5900
# Epoch 17/30
# 40/40 - 0s - 11ms/step - loss: 0.2963 - mae: 0.6081 - val_loss: 0.2829 - val_mae: 0.5901
# Epoch 18/30
# 40/40 - 0s - 11ms/step - loss: 0.2988 - mae: 0.6113 - val_loss: 0.2872 - val_mae: 0.5963
# Epoch 19/30
# 40/40 - 0s - 10ms/step - loss: 0.2922 - mae: 0.6034 - val_loss: 0.2856 - val_mae: 0.5934
# Epoch 20/30
# 40/40 - 0s - 10ms/step - loss: 0.2947 - mae: 0.6083 - val_loss: 0.2845 - val_mae: 0.5911
# Epoch 21/30
# 40/40 - 0s - 10ms/step - loss: 0.2925 - mae: 0.6033 - val_loss: 0.2843 - val_mae: 0.5925
# Epoch 22/30
# 40/40 - 0s - 10ms/step - loss: 0.2895 - mae: 0.5980 - val_loss: 0.2845 - val_mae: 0.5944
# Epoch 23/30
# 40/40 - 0s - 10ms/step - loss: 0.2901 - mae: 0.6004 - val_loss: 0.2834 - val_mae: 0.5874
# Epoch 24/30
# 40/40 - 0s - 10ms/step - loss: 0.2912 - mae: 0.6033 - val_loss: 0.2821 - val_mae: 0.5884
# Epoch 25/30
# 40/40 - 1s - 16ms/step - loss: 0.2926 - mae: 0.6046 - val_loss: 0.2869 - val_mae: 0.5932
# Epoch 26/30
# 40/40 - 0s - 10ms/step - loss: 0.2930 - mae: 0.6050 - val_loss: 0.2823 - val_mae: 0.5900
# Epoch 27/30
# 40/40 - 0s - 10ms/step - loss: 0.2926 - mae: 0.6019 - val_loss: 0.2827 - val_mae: 0.5888
# Epoch 28/30
# 40/40 - 0s - 10ms/step - loss: 0.2903 - mae: 0.6004 - val_loss: 0.2840 - val_mae: 0.5896
# Epoch 29/30
# 40/40 - 0s - 11ms/step - loss: 0.2902 - mae: 0.6005 - val_loss: 0.2827 - val_mae: 0.5915
# Epoch 30/30
# 40/40 - 0s - 10ms/step - loss: 0.2850 - mae: 0.5883 - val_loss: 0.2843 - val_mae: 0.5979
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
#    Displaying Actual vs. Predicted plot for WideResNet...
# Training Complete. | *RMSE: 4,429,167.31* | MAE: 650,033.31 | R2: -0.0031
#
# ================ Model 13/20: Xception ================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training Xception...
# Epoch 1/30
# 40/40 - 53s - 1s/step - loss: 0.3454 - mae: 0.6917 - val_loss: 0.3037 - val_mae: 0.6471
# Epoch 2/30
# 40/40 - 2s - 54ms/step - loss: 0.3206 - mae: 0.6577 - val_loss: 0.2995 - val_mae: 0.6387
# Epoch 3/30
# 40/40 - 2s - 52ms/step - loss: 0.3012 - mae: 0.6281 - val_loss: 0.3157 - val_mae: 0.6564
# Epoch 4/30
# 40/40 - 2s - 52ms/step - loss: 0.2971 - mae: 0.6249 - val_loss: 0.2943 - val_mae: 0.6210
# Epoch 5/30
# 40/40 - 2s - 52ms/step - loss: 0.2805 - mae: 0.5929 - val_loss: 0.3017 - val_mae: 0.6258
# Epoch 6/30
# 40/40 - 2s - 55ms/step - loss: 0.2727 - mae: 0.5808 - val_loss: 0.3091 - val_mae: 0.6304
# Epoch 7/30
# 40/40 - 2s - 55ms/step - loss: 0.2579 - mae: 0.5518 - val_loss: 0.3061 - val_mae: 0.6240
# Epoch 8/30
# 40/40 - 2s - 52ms/step - loss: 0.2557 - mae: 0.5494 - val_loss: 0.3135 - val_mae: 0.6279
# Epoch 9/30
# 40/40 - 2s - 52ms/step - loss: 0.2443 - mae: 0.5315 - val_loss: 0.3029 - val_mae: 0.6135
# Epoch 10/30
# 40/40 - 2s - 53ms/step - loss: 0.2368 - mae: 0.5194 - val_loss: 0.3217 - val_mae: 0.6359
# Epoch 11/30
# 40/40 - 2s - 53ms/step - loss: 0.2307 - mae: 0.5077 - val_loss: 0.3125 - val_mae: 0.6308
# Epoch 12/30
# 40/40 - 2s - 59ms/step - loss: 0.2267 - mae: 0.5094 - val_loss: 0.3096 - val_mae: 0.6223
# Epoch 13/30
# 40/40 - 2s - 55ms/step - loss: 0.2284 - mae: 0.5107 - val_loss: 0.3070 - val_mae: 0.6182
# Epoch 14/30
# 40/40 - 2s - 52ms/step - loss: 0.2249 - mae: 0.5044 - val_loss: 0.3165 - val_mae: 0.6372
# Epoch 15/30
# 40/40 - 2s - 52ms/step - loss: 0.2211 - mae: 0.4950 - val_loss: 0.3136 - val_mae: 0.6277
# Epoch 16/30
# 40/40 - 2s - 52ms/step - loss: 0.2116 - mae: 0.4763 - val_loss: 0.3141 - val_mae: 0.6205
# Epoch 17/30
# 40/40 - 2s - 53ms/step - loss: 0.2153 - mae: 0.4852 - val_loss: 0.3206 - val_mae: 0.6352
# Epoch 18/30
# 40/40 - 2s - 54ms/step - loss: 0.2125 - mae: 0.4814 - val_loss: 0.3148 - val_mae: 0.6301
# Epoch 19/30
# 40/40 - 2s - 56ms/step - loss: 0.2089 - mae: 0.4763 - val_loss: 0.3129 - val_mae: 0.6279
# Epoch 20/30
# 40/40 - 2s - 54ms/step - loss: 0.2065 - mae: 0.4711 - val_loss: 0.3207 - val_mae: 0.6357
# Epoch 21/30
# 40/40 - 2s - 55ms/step - loss: 0.2053 - mae: 0.4662 - val_loss: 0.3156 - val_mae: 0.6303
# Epoch 22/30
# 40/40 - 2s - 52ms/step - loss: 0.2065 - mae: 0.4646 - val_loss: 0.3129 - val_mae: 0.6240
# Epoch 23/30
# 40/40 - 2s - 52ms/step - loss: 0.2020 - mae: 0.4626 - val_loss: 0.3119 - val_mae: 0.6222
# Epoch 24/30
# 40/40 - 2s - 53ms/step - loss: 0.2043 - mae: 0.4607 - val_loss: 0.3220 - val_mae: 0.6362
# Epoch 25/30
# 40/40 - 2s - 55ms/step - loss: 0.2049 - mae: 0.4648 - val_loss: 0.3128 - val_mae: 0.6228
# Epoch 26/30
# 40/40 - 2s - 53ms/step - loss: 0.2015 - mae: 0.4568 - val_loss: 0.3118 - val_mae: 0.6228
# Epoch 27/30
# 40/40 - 2s - 53ms/step - loss: 0.1999 - mae: 0.4580 - val_loss: 0.3128 - val_mae: 0.6260
# Epoch 28/30
# 40/40 - 2s - 52ms/step - loss: 0.2016 - mae: 0.4574 - val_loss: 0.3099 - val_mae: 0.6217
# Epoch 29/30
# 40/40 - 2s - 52ms/step - loss: 0.1996 - mae: 0.4575 - val_loss: 0.3065 - val_mae: 0.6175
# Epoch 30/30
# 40/40 - 2s - 52ms/step - loss: 0.2001 - mae: 0.4555 - val_loss: 0.3162 - val_mae: 0.6292
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 512ms/step
#    Displaying Actual vs. Predicted plot for Xception...
# Training Complete. | *RMSE: 4,525,277.16* | MAE: 754,725.40 | R2: -0.0471
#
# ================ Model 14/20: Residual Attention Neural Network ================
# Training Residual Attention Neural Network...
# Epoch 1/30
# 40/40 - 9s - 237ms/step - loss: 0.3489 - mae: 0.6973 - val_loss: 0.3097 - val_mae: 0.6525
# Epoch 2/30
# 40/40 - 0s - 12ms/step - loss: 0.3426 - mae: 0.6877 - val_loss: 0.3015 - val_mae: 0.6348
# Epoch 3/30
# 40/40 - 0s - 11ms/step - loss: 0.3338 - mae: 0.6720 - val_loss: 0.3018 - val_mae: 0.6252
# Epoch 4/30
# 40/40 - 0s - 11ms/step - loss: 0.3273 - mae: 0.6629 - val_loss: 0.2908 - val_mae: 0.6028
# Epoch 5/30
# 40/40 - 0s - 11ms/step - loss: 0.3191 - mae: 0.6498 - val_loss: 0.2899 - val_mae: 0.5959
# Epoch 6/30
# 40/40 - 0s - 11ms/step - loss: 0.3167 - mae: 0.6426 - val_loss: 0.2871 - val_mae: 0.5956
# Epoch 7/30
# 40/40 - 0s - 10ms/step - loss: 0.3125 - mae: 0.6378 - val_loss: 0.2861 - val_mae: 0.5898
# Epoch 8/30
# 40/40 - 0s - 11ms/step - loss: 0.3157 - mae: 0.6380 - val_loss: 0.2871 - val_mae: 0.5938
# Epoch 9/30
# 40/40 - 0s - 10ms/step - loss: 0.3076 - mae: 0.6266 - val_loss: 0.2891 - val_mae: 0.5936
# Epoch 10/30
# 40/40 - 0s - 11ms/step - loss: 0.3095 - mae: 0.6301 - val_loss: 0.2866 - val_mae: 0.5916
# Epoch 11/30
# 40/40 - 1s - 15ms/step - loss: 0.3036 - mae: 0.6227 - val_loss: 0.2876 - val_mae: 0.5946
# Epoch 12/30
# 40/40 - 0s - 11ms/step - loss: 0.3021 - mae: 0.6221 - val_loss: 0.2889 - val_mae: 0.5974
# Epoch 13/30
# 40/40 - 0s - 12ms/step - loss: 0.3019 - mae: 0.6192 - val_loss: 0.2875 - val_mae: 0.5950
# Epoch 14/30
# 40/40 - 1s - 14ms/step - loss: 0.3009 - mae: 0.6154 - val_loss: 0.2857 - val_mae: 0.5925
# Epoch 15/30
# 40/40 - 1s - 13ms/step - loss: 0.2995 - mae: 0.6135 - val_loss: 0.2850 - val_mae: 0.5941
# Epoch 16/30
# 40/40 - 1s - 14ms/step - loss: 0.2998 - mae: 0.6154 - val_loss: 0.2854 - val_mae: 0.5934
# Epoch 17/30
# 40/40 - 1s - 15ms/step - loss: 0.2951 - mae: 0.6109 - val_loss: 0.2872 - val_mae: 0.5964
# Epoch 18/30
# 40/40 - 1s - 16ms/step - loss: 0.2942 - mae: 0.6077 - val_loss: 0.2852 - val_mae: 0.5922
# Epoch 19/30
# 40/40 - 1s - 14ms/step - loss: 0.2993 - mae: 0.6118 - val_loss: 0.2850 - val_mae: 0.5927
# Epoch 20/30
# 40/40 - 1s - 13ms/step - loss: 0.2959 - mae: 0.6078 - val_loss: 0.2843 - val_mae: 0.5923
# Epoch 21/30
# 40/40 - 0s - 11ms/step - loss: 0.2915 - mae: 0.6003 - val_loss: 0.2870 - val_mae: 0.5945
# Epoch 22/30
# 40/40 - 0s - 11ms/step - loss: 0.2893 - mae: 0.5987 - val_loss: 0.2847 - val_mae: 0.5925
# Epoch 23/30
# 40/40 - 0s - 11ms/step - loss: 0.2914 - mae: 0.5978 - val_loss: 0.2876 - val_mae: 0.5959
# Epoch 24/30
# 40/40 - 1s - 13ms/step - loss: 0.2883 - mae: 0.5952 - val_loss: 0.2869 - val_mae: 0.5945
# Epoch 25/30
# 40/40 - 0s - 11ms/step - loss: 0.2941 - mae: 0.6045 - val_loss: 0.2838 - val_mae: 0.5927
# Epoch 26/30
# 40/40 - 0s - 11ms/step - loss: 0.2924 - mae: 0.6035 - val_loss: 0.2835 - val_mae: 0.5908
# Epoch 27/30
# 40/40 - 0s - 11ms/step - loss: 0.2877 - mae: 0.5960 - val_loss: 0.2874 - val_mae: 0.5935
# Epoch 28/30
# 40/40 - 0s - 11ms/step - loss: 0.2905 - mae: 0.6011 - val_loss: 0.2852 - val_mae: 0.5909
# Epoch 29/30
# 40/40 - 1s - 15ms/step - loss: 0.2897 - mae: 0.5998 - val_loss: 0.2827 - val_mae: 0.5906
# Epoch 30/30
# 40/40 - 0s - 11ms/step - loss: 0.2906 - mae: 0.5975 - val_loss: 0.2825 - val_mae: 0.5937
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
#    Displaying Actual vs. Predicted plot for Residual Attention Neural Network...
# Training Complete. | *RMSE: 4,434,700.94* | MAE: 645,177.01 | R2: -0.0056
#
# ================ Model 15/20: Squeeze and Excitation Networks ================
# Training Squeeze and Excitation Networks...
# Epoch 1/30
# 40/40 - 10s - 242ms/step - loss: 0.3528 - mae: 0.7013 - val_loss: 0.3126 - val_mae: 0.6573
# Epoch 2/30
# 40/40 - 0s - 11ms/step - loss: 0.3474 - mae: 0.6939 - val_loss: 0.3085 - val_mae: 0.6491
# Epoch 3/30
# ...
# Epoch 2/30
# 40/40 - 2s - 41ms/step - loss: 0.3182 - mae: 0.6555 - val_loss: 0.2980 - val_mae: 0.6397
# Epoch 3/30
# 40/40 - 2s - 39ms/step - loss: 0.3048 - mae: 0.6316 - val_loss: 0.2900 - val_mae: 0.6201
# Epoch 4/30
# 40/40 - 2s - 39ms/step - loss: 0.2918 - mae: 0.6095 - val_loss: 0.2784 - val_mae: 0.5951
# Epoch 5/30
# 40/40 - 2s - 39ms/step - loss: 0.2809 - mae: 0.5910 - val_loss: 0.2809 - val_mae: 0.5936
# Epoch 6/30
# 40/40 - 2s - 38ms/step - loss: 0.2649 - mae: 0.5655 - val_loss: 0.2728 - val_mae: 0.5844
# Epoch 7/30
# 40/40 - 2s - 49ms/step - loss: 0.2559 - mae: 0.5483 - val_loss: 0.2883 - val_mae: 0.6057
# Epoch 8/30
# 40/40 - 2s - 45ms/step - loss: 0.2532 - mae: 0.5475 - val_loss: 0.2815 - val_mae: 0.5936
# Epoch 9/30
# 40/40 - 2s - 39ms/step - loss: 0.2487 - mae: 0.5408 - val_loss: 0.2788 - val_mae: 0.5890
# Epoch 10/30
# 40/40 - 2s - 39ms/step - loss: 0.2426 - mae: 0.5293 - val_loss: 0.2811 - val_mae: 0.5989
# Epoch 11/30
# 40/40 - 2s - 39ms/step - loss: 0.2377 - mae: 0.5235 - val_loss: 0.2842 - val_mae: 0.5953
# Epoch 12/30
# 40/40 - 2s - 38ms/step - loss: 0.2379 - mae: 0.5258 - val_loss: 0.3057 - val_mae: 0.6262
# Epoch 13/30
# 40/40 - 2s - 38ms/step - loss: 0.2329 - mae: 0.5122 - val_loss: 0.2946 - val_mae: 0.6132
# Epoch 14/30
# 40/40 - 2s - 39ms/step - loss: 0.2354 - mae: 0.5164 - val_loss: 0.2858 - val_mae: 0.5987
# Epoch 15/30
# 40/40 - 2s - 44ms/step - loss: 0.2221 - mae: 0.4932 - val_loss: 0.2959 - val_mae: 0.6135
# Epoch 16/30
# 40/40 - 2s - 45ms/step - loss: 0.2170 - mae: 0.4841 - val_loss: 0.3000 - val_mae: 0.6174
# Epoch 17/30
# 40/40 - 2s - 39ms/step - loss: 0.2193 - mae: 0.4890 - val_loss: 0.3012 - val_mae: 0.6239
# Epoch 18/30
# 40/40 - 2s - 39ms/step - loss: 0.2216 - mae: 0.5013 - val_loss: 0.2952 - val_mae: 0.6129
# Epoch 19/30
# 40/40 - 2s - 39ms/step - loss: 0.2111 - mae: 0.4805 - val_loss: 0.3057 - val_mae: 0.6257
# Epoch 20/30
# 40/40 - 2s - 38ms/step - loss: 0.2126 - mae: 0.4805 - val_loss: 0.2951 - val_mae: 0.6136
# Epoch 21/30
# 40/40 - 2s - 40ms/step - loss: 0.2136 - mae: 0.4796 - val_loss: 0.3037 - val_mae: 0.6241
# Epoch 22/30
# 40/40 - 2s - 38ms/step - loss: 0.2095 - mae: 0.4787 - val_loss: 0.3015 - val_mae: 0.6214
# Epoch 23/30
# 40/40 - 2s - 43ms/step - loss: 0.2090 - mae: 0.4776 - val_loss: 0.2963 - val_mae: 0.6137
# Epoch 24/30
# 40/40 - 2s - 45ms/step - loss: 0.2094 - mae: 0.4809 - val_loss: 0.2887 - val_mae: 0.6033
# Epoch 25/30
# 40/40 - 2s - 39ms/step - loss: 0.2082 - mae: 0.4723 - val_loss: 0.2970 - val_mae: 0.6154
# Epoch 26/30
# 40/40 - 2s - 39ms/step - loss: 0.1995 - mae: 0.4591 - val_loss: 0.2923 - val_mae: 0.6084
# Epoch 27/30
# 40/40 - 2s - 39ms/step - loss: 0.2006 - mae: 0.4621 - val_loss: 0.2929 - val_mae: 0.6117
# Epoch 28/30
# 40/40 - 2s - 39ms/step - loss: 0.1990 - mae: 0.4587 - val_loss: 0.2944 - val_mae: 0.6135
# Epoch 29/30
# 40/40 - 2s - 38ms/step - loss: 0.2031 - mae: 0.4620 - val_loss: 0.3042 - val_mae: 0.6211
# Epoch 30/30
# 40/40 - 2s - 38ms/step - loss: 0.2008 - mae: 0.4583 - val_loss: 0.2952 - val_mae: 0.6175
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step
#    Displaying Actual vs. Predicted plot for DenseNet...
# Training Complete. | *RMSE: 4,448,331.02* | MAE: 674,700.94 | R2: -0.0118
#
# ================ Model 18/20: MobileNet V2 ================
# /tmp/ipython-input-2466553242.py:296: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_cnn = BaseModel(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training MobileNet V2...
# Epoch 1/30
# 40/40 - 49s - 1s/step - loss: 0.3444 - mae: 0.6915 - val_loss: 0.3084 - val_mae: 0.6544
# Epoch 2/30
# 40/40 - 1s - 21ms/step - loss: 0.3163 - mae: 0.6533 - val_loss: 0.3172 - val_mae: 0.6655
# Epoch 3/30
# 40/40 - 1s - 19ms/step - loss: 0.2981 - mae: 0.6223 - val_loss: 0.3064 - val_mae: 0.6485
# Epoch 4/30
# 40/40 - 1s - 19ms/step - loss: 0.2811 - mae: 0.5933 - val_loss: 0.2967 - val_mae: 0.6216
# Epoch 5/30
# 40/40 - 1s - 19ms/step - loss: 0.2666 - mae: 0.5671 - val_loss: 0.3101 - val_mae: 0.6344
# Epoch 6/30
# 40/40 - 1s - 19ms/step - loss: 0.2581 - mae: 0.5526 - val_loss: 0.3056 - val_mae: 0.6294
# Epoch 7/30
# 40/40 - 1s - 22ms/step - loss: 0.2541 - mae: 0.5478 - val_loss: 0.3119 - val_mae: 0.6365
# Epoch 8/30
# 40/40 - 1s - 27ms/step - loss: 0.2491 - mae: 0.5377 - val_loss: 0.3036 - val_mae: 0.6207
# Epoch 9/30
# 40/40 - 1s - 25ms/step - loss: 0.2434 - mae: 0.5362 - val_loss: 0.3099 - val_mae: 0.6314
# Epoch 10/30
# 40/40 - 1s - 26ms/step - loss: 0.2420 - mae: 0.5325 - val_loss: 0.3088 - val_mae: 0.6316
# Epoch 11/30
# 40/40 - 1s - 18ms/step - loss: 0.2268 - mae: 0.5070 - val_loss: 0.3048 - val_mae: 0.6196
# Epoch 12/30
# 40/40 - 1s - 18ms/step - loss: 0.2220 - mae: 0.5025 - val_loss: 0.3153 - val_mae: 0.6341
# Epoch 13/30
# 40/40 - 1s - 18ms/step - loss: 0.2224 - mae: 0.4992 - val_loss: 0.3116 - val_mae: 0.6257
# Epoch 14/30
# 40/40 - 1s - 18ms/step - loss: 0.2143 - mae: 0.4858 - val_loss: 0.3059 - val_mae: 0.6203
# Epoch 15/30
# 40/40 - 1s - 19ms/step - loss: 0.2176 - mae: 0.4880 - val_loss: 0.2967 - val_mae: 0.6088
# Epoch 16/30
# 40/40 - 1s - 19ms/step - loss: 0.2163 - mae: 0.4887 - val_loss: 0.3010 - val_mae: 0.6148
# Epoch 17/30
# 40/40 - 1s - 19ms/step - loss: 0.2099 - mae: 0.4759 - val_loss: 0.2981 - val_mae: 0.6160
# Epoch 18/30
# 40/40 - 1s - 18ms/step - loss: 0.2169 - mae: 0.4831 - val_loss: 0.3098 - val_mae: 0.6299
# Epoch 19/30
# 40/40 - 1s - 18ms/step - loss: 0.2098 - mae: 0.4714 - val_loss: 0.3008 - val_mae: 0.6192
# Epoch 20/30
# 40/40 - 1s - 18ms/step - loss: 0.2096 - mae: 0.4741 - val_loss: 0.2995 - val_mae: 0.6130
# Epoch 21/30
# 40/40 - 1s - 19ms/step - loss: 0.2103 - mae: 0.4759 - val_loss: 0.3078 - val_mae: 0.6259
# Epoch 22/30
# 40/40 - 1s - 18ms/step - loss: 0.2078 - mae: 0.4711 - val_loss: 0.3090 - val_mae: 0.6274
# Epoch 23/30
# 40/40 - 2s - 39ms/step - loss: 0.2039 - mae: 0.4664 - val_loss: 0.3158 - val_mae: 0.6402
# Epoch 24/30
# 40/40 - 1s - 24ms/step - loss: 0.2041 - mae: 0.4679 - val_loss: 0.3047 - val_mae: 0.6188
# Epoch 25/30
# 40/40 - 1s - 20ms/step - loss: 0.2077 - mae: 0.4774 - val_loss: 0.3072 - val_mae: 0.6267
# Epoch 26/30
# 40/40 - 1s - 20ms/step - loss: 0.2069 - mae: 0.4655 - val_loss: 0.3058 - val_mae: 0.6247
# Epoch 27/30
# 40/40 - 1s - 19ms/step - loss: 0.2034 - mae: 0.4601 - val_loss: 0.3069 - val_mae: 0.6252
# Epoch 28/30
# 40/40 - 1s - 19ms/step - loss: 0.2026 - mae: 0.4623 - val_loss: 0.3047 - val_mae: 0.6264
# Epoch 29/30
# 40/40 - 1s - 19ms/step - loss: 0.2016 - mae: 0.4639 - val_loss: 0.3064 - val_mae: 0.6209
# Epoch 30/30
# 40/40 - 1s - 19ms/step - loss: 0.2009 - mae: 0.4591 - val_loss: 0.3077 - val_mae: 0.6278
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 600ms/step
#    Displaying Actual vs. Predicted plot for MobileNet V2...
# Training Complete. | *RMSE: 4,465,469.78* | MAE: 691,009.52 | R2: -0.0196
#
# ================ Model 19/20: Capsulenet ================
# Training Capsulenet...
# Epoch 1/30
# 40/40 - 10s - 239ms/step - loss: 0.3516 - mae: 0.6998 - val_loss: 0.3139 - val_mae: 0.6603
# Epoch 2/30
# 40/40 - 0s - 12ms/step - loss: 0.3440 - mae: 0.6900 - val_loss: 0.3062 - val_mae: 0.6459
# Epoch 3/30
# 40/40 - 0s - 11ms/step - loss: 0.3340 - mae: 0.6747 - val_loss: 0.3031 - val_mae: 0.6350
# Epoch 4/30
# 40/40 - 0s - 11ms/step - loss: 0.3221 - mae: 0.6549 - val_loss: 0.3033 - val_mae: 0.6266
# Epoch 5/30
# 40/40 - 0s - 11ms/step - loss: 0.3204 - mae: 0.6464 - val_loss: 0.2926 - val_mae: 0.6014
# Epoch 6/30
# 40/40 - 0s - 11ms/step - loss: 0.3166 - mae: 0.6418 - val_loss: 0.2898 - val_mae: 0.5959
# Epoch 7/30
# 40/40 - 0s - 11ms/step - loss: 0.3091 - mae: 0.6282 - val_loss: 0.2889 - val_mae: 0.5940
# Epoch 8/30
# 40/40 - 0s - 11ms/step - loss: 0.3125 - mae: 0.6330 - val_loss: 0.2895 - val_mae: 0.5987
# Epoch 9/30
# 40/40 - 0s - 11ms/step - loss: 0.3060 - mae: 0.6266 - val_loss: 0.2874 - val_mae: 0.5934
# Epoch 10/30
# 40/40 - 1s - 13ms/step - loss: 0.3064 - mae: 0.6248 - val_loss: 0.2875 - val_mae: 0.5935
# Epoch 11/30
# 40/40 - 0s - 11ms/step - loss: 0.3027 - mae: 0.6229 - val_loss: 0.2880 - val_mae: 0.5945
# Epoch 12/30
# 40/40 - 0s - 11ms/step - loss: 0.3024 - mae: 0.6217 - val_loss: 0.2867 - val_mae: 0.5935
# Epoch 13/30
# 40/40 - 0s - 10ms/step - loss: 0.3033 - mae: 0.6191 - val_loss: 0.2895 - val_mae: 0.5984
# Epoch 14/30
# 40/40 - 0s - 11ms/step - loss: 0.2990 - mae: 0.6143 - val_loss: 0.2858 - val_mae: 0.5939
# Epoch 15/30
# 40/40 - 0s - 10ms/step - loss: 0.2978 - mae: 0.6127 - val_loss: 0.2867 - val_mae: 0.5940
# Epoch 16/30
# 40/40 - 0s - 12ms/step - loss: 0.2987 - mae: 0.6107 - val_loss: 0.2854 - val_mae: 0.5928
# Epoch 17/30
# 40/40 - 0s - 11ms/step - loss: 0.2940 - mae: 0.6055 - val_loss: 0.2859 - val_mae: 0.5929
# Epoch 18/30
# 40/40 - 0s - 10ms/step - loss: 0.2943 - mae: 0.6073 - val_loss: 0.2846 - val_mae: 0.5913
# Epoch 19/30
# 40/40 - 0s - 11ms/step - loss: 0.2946 - mae: 0.6049 - val_loss: 0.2835 - val_mae: 0.5917
# Epoch 20/30
# 40/40 - 0s - 10ms/step - loss: 0.2908 - mae: 0.6036 - val_loss: 0.2839 - val_mae: 0.5922
# Epoch 21/30
# 40/40 - 1s - 13ms/step - loss: 0.2905 - mae: 0.6043 - val_loss: 0.2830 - val_mae: 0.5934
# Epoch 22/30
# 40/40 - 0s - 10ms/step - loss: 0.2886 - mae: 0.6005 - val_loss: 0.2838 - val_mae: 0.5938
# Epoch 23/30
# 40/40 - 0s - 12ms/step - loss: 0.2933 - mae: 0.6038 - val_loss: 0.2855 - val_mae: 0.5937
# Epoch 24/30
# 40/40 - 1s - 16ms/step - loss: 0.2927 - mae: 0.6032 - val_loss: 0.2804 - val_mae: 0.5864
# Epoch 25/30
# 40/40 - 1s - 14ms/step - loss: 0.2879 - mae: 0.5961 - val_loss: 0.2836 - val_mae: 0.5908
# Epoch 26/30
# 40/40 - 1s - 14ms/step - loss: 0.2914 - mae: 0.6002 - val_loss: 0.2816 - val_mae: 0.5900
# Epoch 27/30
# 40/40 - 1s - 15ms/step - loss: 0.2861 - mae: 0.5936 - val_loss: 0.2933 - val_mae: 0.6131
# Epoch 28/30
# 40/40 - 1s - 16ms/step - loss: 0.2884 - mae: 0.5948 - val_loss: 0.2826 - val_mae: 0.5930
# Epoch 29/30
# 40/40 - 1s - 13ms/step - loss: 0.2826 - mae: 0.5902 - val_loss: 0.2823 - val_mae: 0.5901
# Epoch 30/30
# 40/40 - 0s - 11ms/step - loss: 0.2846 - mae: 0.5902 - val_loss: 0.2834 - val_mae: 0.5904
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step
#    Displaying Actual vs. Predicted plot for Capsulenet...
# Training Complete. | *RMSE: 4,446,905.71* | MAE: 641,910.75 | R2: -0.0112
#
# ================ Model 20/20: HRNet V2 ================
# Training HRNet V2...
# Epoch 1/30
# 40/40 - 10s - 241ms/step - loss: 0.3516 - mae: 0.7016 - val_loss: 0.3109 - val_mae: 0.6550
# Epoch 2/30
# 40/40 - 4s - 91ms/step - loss: 0.3460 - mae: 0.6918 - val_loss: 0.3058 - val_mae: 0.6450
# Epoch 3/30
# 40/40 - 0s - 11ms/step - loss: 0.3365 - mae: 0.6788 - val_loss: 0.3021 - val_mae: 0.6356
# Epoch 4/30
# 40/40 - 0s - 11ms/step - loss: 0.3289 - mae: 0.6638 - val_loss: 0.2974 - val_mae: 0.6172
# Epoch 5/30
# 40/40 - 0s - 11ms/step - loss: 0.3220 - mae: 0.6536 - val_loss: 0.2933 - val_mae: 0.6081
# Epoch 6/30
# 40/40 - 0s - 11ms/step - loss: 0.3195 - mae: 0.6489 - val_loss: 0.2929 - val_mae: 0.6036
# Epoch 7/30
# 40/40 - 0s - 10ms/step - loss: 0.3166 - mae: 0.6414 - val_loss: 0.2883 - val_mae: 0.5981
# Epoch 8/30
# 40/40 - 0s - 11ms/step - loss: 0.3110 - mae: 0.6360 - val_loss: 0.2891 - val_mae: 0.5955
# Epoch 9/30
# 40/40 - 0s - 10ms/step - loss: 0.3111 - mae: 0.6344 - val_loss: 0.2879 - val_mae: 0.5948
# Epoch 10/30
# 40/40 - 0s - 11ms/step - loss: 0.3033 - mae: 0.6228 - val_loss: 0.2893 - val_mae: 0.5995
# Epoch 11/30
# 40/40 - 1s - 15ms/step - loss: 0.3031 - mae: 0.6247 - val_loss: 0.2891 - val_mae: 0.5972
# Epoch 12/30
# 40/40 - 0s - 11ms/step - loss: 0.3029 - mae: 0.6211 - val_loss: 0.2880 - val_mae: 0.5936
# Epoch 13/30
# 40/40 - 0s - 10ms/step - loss: 0.3027 - mae: 0.6189 - val_loss: 0.2857 - val_mae: 0.5915
# Epoch 14/30
# 40/40 - 0s - 12ms/step - loss: 0.2988 - mae: 0.6135 - val_loss: 0.2848 - val_mae: 0.5911
# Epoch 15/30
# 40/40 - 0s - 10ms/step - loss: 0.2997 - mae: 0.6181 - val_loss: 0.2834 - val_mae: 0.5919
# Epoch 16/30
# 40/40 - 1s - 13ms/step - loss: 0.2932 - mae: 0.6067 - val_loss: 0.2854 - val_mae: 0.5921
# Epoch 17/30
# 40/40 - 1s - 14ms/step - loss: 0.2954 - mae: 0.6075 - val_loss: 0.2838 - val_mae: 0.5909
# Epoch 18/30
# 40/40 - 1s - 13ms/step - loss: 0.2959 - mae: 0.6076 - val_loss: 0.2835 - val_mae: 0.5896
# Epoch 19/30
# 40/40 - 1s - 16ms/step - loss: 0.2950 - mae: 0.6113 - val_loss: 0.2839 - val_mae: 0.5908
# Epoch 20/30
# 40/40 - 1s - 27ms/step - loss: 0.2928 - mae: 0.6026 - val_loss: 0.2827 - val_mae: 0.5904
# Epoch 21/30
# 40/40 - 0s - 11ms/step - loss: 0.2918 - mae: 0.6037 - val_loss: 0.2832 - val_mae: 0.5897
# Epoch 22/30
# 40/40 - 0s - 11ms/step - loss: 0.2921 - mae: 0.6050 - val_loss: 0.2809 - val_mae: 0.5859
# Epoch 23/30
# 40/40 - 0s - 12ms/step - loss: 0.2906 - mae: 0.5990 - val_loss: 0.2843 - val_mae: 0.5932
# Epoch 24/30
# 40/40 - 0s - 11ms/step - loss: 0.2888 - mae: 0.5998 - val_loss: 0.2805 - val_mae: 0.5891
# Epoch 25/30
# 40/40 - 0s - 11ms/step - loss: 0.2886 - mae: 0.5969 - val_loss: 0.2818 - val_mae: 0.5908
# Epoch 26/30
# 40/40 - 0s - 11ms/step - loss: 0.2853 - mae: 0.5938 - val_loss: 0.2833 - val_mae: 0.5932
# Epoch 27/30
# 40/40 - 0s - 11ms/step - loss: 0.2906 - mae: 0.5967 - val_loss: 0.2815 - val_mae: 0.5891
# Epoch 28/30
# 40/40 - 0s - 11ms/step - loss: 0.2868 - mae: 0.5949 - val_loss: 0.2872 - val_mae: 0.5938
# Epoch 29/30
# 40/40 - 0s - 10ms/step - loss: 0.2825 - mae: 0.5865 - val_loss: 0.2824 - val_mae: 0.5918
# Epoch 30/30
# 40/40 - 0s - 11ms/step - loss: 0.2886 - mae: 0.5934 - val_loss: 0.2798 - val_mae: 0.5907
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
#    Displaying Actual vs. Predicted plot for HRNet V2...
# Training Complete. | *RMSE: 4,438,355.58* | MAE: 645,750.69 | R2: -0.0073
#
# ==================================================
#              MODEL PERFORMANCE SUMMARY
# ==================================================
# | Model Name                                 |        RMSE |    MAE |          R2 | Notes      |
# |:-------------------------------------------|------------:|-------:|------------:|:-----------|
# | WideResNet                                 | 4.42917e+06 | 650033 | -0.00311852 | Successful |
# | Residual Attention Neural Network          | 4.4347e+06  | 645177 | -0.00562659 | Successful |
# | Squeeze and Excitation Networks            | 4.43791e+06 | 648199 | -0.00708284 | Successful |
# | FractalNet                                 | 4.43802e+06 | 647853 | -0.00713178 | Successful |
# | HRNet V2                                   | 4.43836e+06 | 645751 | -0.00728475 | Successful |
# | Highway                                    | 4.43993e+06 | 648319 | -0.00799869 | Successful |
# | NiN                                        | 4.44155e+06 | 648816 | -0.00873535 | Successful |
# | AlexNet                                    | 4.44584e+06 | 646430 | -0.0106866  | Successful |
# | Google LeNet                               | 4.44655e+06 | 644307 | -0.0110067  | Successful |
# | Capsulenet                                 | 4.44691e+06 | 641911 | -0.0111694  | Successful |
# | Competitive Squeeze and Excitation Network | 4.44759e+06 | 647417 | -0.0114795  | Successful |
# | InceptionV4                                | 4.44795e+06 | 648126 | -0.011645   | Successful |
# | DenseNet                                   | 4.44833e+06 | 674701 | -0.0118177  | Successful |
# | ResNet                                     | 4.44838e+06 | 646610 | -0.0118396  | Successful |
# | InceptionV4 ResNet                         | 4.45035e+06 | 663099 | -0.0127386  | Successful |
# | ZNet                                       | 4.45624e+06 | 643388 | -0.0154171  | Successful |
# | MobileNet V2                               | 4.46547e+06 | 691010 | -0.0196295  | Successful |
# | VGG                                        | 4.46954e+06 | 710168 | -0.0214878  | Successful |
# | Xception                                   | 4.52528e+06 | 754725 | -0.0471248  | Successful |
# | InceptionV3                                | 4.66797e+06 | 768856 | -0.114202   | Successful |
# ==================================================
# 🥇 Best Model: WideResNet (RMSE: 4,429,167.31)
# ==================================================
#
# Displaying Final Summary Plots:
# ✅ Displayed: Best Model Actual vs. Predicted Plot
# ✅ Displayed: All Model RMSE Comparison Plot
# ✅ Displayed: Best Model Training History Plot
